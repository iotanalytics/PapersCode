# %% [markdown]
# # IoT anomaly detection using power meter

# %% [markdown]
# ------

# %% [markdown]
# ## Model training phase

# %% [markdown]
# Load training data. And testing datasets with and without anomalies

# %%
import pandas
import matplotlib.pyplot as plotter
from pathlib import Path
import seaborn

# %%
data = Path("../data/summer_final/")
files = list(data.iterdir())

for file in files:
    print(f"Loading data from {file}")
# Out:
# Loading data from ../data/summer_final/summer_final_tx.csv
# Loading data from ../data/summer_final/summer_final_cpu.csv
# Loading data from ../data/summer_final/summer_final_voltage.csv
# Loading data from ../data/summer_final/summer_final_disk.csv
# Loading data from ../data/summer_final/summer_final_rx.csv
# Loading data from ../data/summer_final/summer_final_power.csv

# %%
disk = pandas.read_csv(str(data/"summer_final_disk.csv")).drop("Unnamed: 0", axis=1)
cpu = pandas.read_csv(str(data/"summer_final_cpu.csv")).drop("Unnamed: 0", axis=1)
power = pandas.read_csv(str(data/"summer_final_power.csv")).drop("Unnamed: 0", axis=1)
tx = pandas.read_csv(str(data/"summer_final_tx.csv")).drop("Unnamed: 0", axis=1)
rx = pandas.read_csv(str(data/"summer_final_rx.csv")).drop("Unnamed: 0", axis=1)

# %% [markdown]
# A lot of problems in life can be solved using preprocessing. In this case, we'll try median filtering to remove noise from the power signal

# %%
from scipy.signal import medfilt

print("Filtering power")
print("Before filtering")
fig = plotter.figure(figsize=(25, 5))
plotter.plot(power["Power12"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("After filtering")
power = pandas.DataFrame({"Power12": medfilt(power["Power12"].as_matrix().ravel(), kernel_size=5)})
fig = plotter.figure(figsize=(25, 5))
plotter.plot(power["Power12"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("Filtering CPU")
print("Before filtering")
fig = plotter.figure(figsize=(25, 5))
plotter.plot(cpu["CPU_user"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("After filtering")
cpu = pandas.DataFrame({"CPU_user": medfilt(cpu["CPU_user"].as_matrix().ravel(), kernel_size=5)})
fig = plotter.figure(figsize=(25, 5))
plotter.plot(cpu["CPU_user"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("Filtering TX")
print("Before filtering")
fig = plotter.figure(figsize=(25, 5))
plotter.plot(tx["net_TX"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("After filtering")
tx = pandas.DataFrame({"net_TX": medfilt(tx["net_TX"].as_matrix().ravel(), kernel_size=5)})
fig = plotter.figure(figsize=(25, 5))
plotter.plot(tx["net_TX"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("Filtering RX")
print("Before filtering")
fig = plotter.figure(figsize=(25, 5))
plotter.plot(rx["net_RX"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("After filtering")
rx = pandas.DataFrame({"net_RX": medfilt(rx["net_RX"].as_matrix().ravel(), kernel_size=5)})
fig = plotter.figure(figsize=(25, 5))
plotter.plot(rx["net_RX"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("Filtering Disk")
print("Before filtering")
fig = plotter.figure(figsize=(25, 5))
plotter.plot(disk["disk_p2"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()

print("After filtering")
disk = pandas.DataFrame({"disk_p2": medfilt(disk["disk_p2"].as_matrix().ravel(), kernel_size=5)})
fig = plotter.figure(figsize=(25, 5))
plotter.plot(disk["disk_p2"].as_matrix().ravel()[0: 500], linewidth=0.5, label="Before filtering")
plotter.show()
# Out:
# Filtering power
# Before filtering
# After filtering
# Filtering CPU
# Before filtering
# After filtering
# Filtering TX
# Before filtering
# After filtering
# Filtering RX
# Before filtering
# After filtering
# Filtering Disk
# Before filtering
# After filtering

# %% [markdown]
# Combine all dataframes into a single dataset

# %%
all_data = pandas.concat([cpu, tx, rx, disk, power.clip(lower=1200)], axis=1, join="inner").fillna(method="ffill").fillna(0)
all_data.describe()
# Out:
#            CPU_user        net_TX        net_RX       disk_p2       Power12
# count  8.856000e+04  8.856000e+04  8.856000e+04  8.856000e+04  88560.000000
# mean   4.160710e+02  7.739434e+01  4.190589e+01  2.218976e+02   1611.737387
# std    4.914119e+05  9.459888e+04  9.237828e+04  2.734597e+05    190.917050
# min   -1.034063e+08 -1.990604e+07 -1.943882e+07 -5.754321e+07   1200.000000
# 25%    1.316667e+01  1.500000e+01  1.000000e+01  0.000000e+00   1410.975610
# 50%    5.050000e+02  9.750000e+01  1.000000e+01  0.000000e+00   1634.146341
# 75%    5.443333e+02  9.750000e+01  8.483333e+01  0.000000e+00   1712.195122
# max    1.034063e+08  1.990625e+07  1.943893e+07  5.754321e+07   2197.967480

# %%
fig = plotter.figure(figsize=(25, 5))
plotter.plot(all_data["CPU_user"][:1000], label="CPU", linewidth=0.5)
plotter.plot(all_data["Power12"][:1000], label="Power", linewidth=0.5)
plotter.plot(all_data["net_TX"][:1000], label="TX", linewidth=0.5)
plotter.legend()
plotter.show()

# %%
all_data.columns
# Out:
# Index(['CPU_user', 'net_TX', 'net_RX', 'disk_p2', 'Power12'], dtype='object')

# %%
all_data.plot(kind="box")
plotter.show()

#all_data.plot(kind="density")
#plotter.show()

all_data.plot()
plotter.show()

# %%
training_set = all_data[:50000]
validation_set = all_data[50000:60000]
testing_set = all_data[60000:]

# %%
fig = plotter.figure(figsize=(25, 5))
plotter.plot(training_set["CPU_user"][:20000], label="CPU", linewidth=0.5)
plotter.plot(training_set["Power12"][:20000], label="Power", linewidth=0.5)
plotter.plot(training_set["net_TX"][:20000], label="TX", linewidth=0.5)
plotter.legend()
plotter.show()

# %%
training_set.head(1000)
# Out:
#         CPU_user     net_TX  net_RX  disk_p2      Power12
# 0       6.500000  78.000000     8.0      0.0  1330.487805
# 1      11.166667  97.500000    10.0      0.0  1358.130081
# 2      11.666667  97.500000    10.0      0.0  1374.390244
# 3      11.166667  97.500000    10.0      0.0  1374.390244
# 4      11.166667  97.500000    10.0      0.0  1358.130081
# 5      12.333333  97.500000    10.0      0.0  1374.390244
# 6      12.333333  97.500000    10.0      0.0  1380.487805
# 7      11.166667  97.500000    10.0      0.0  1380.487805
# 8      12.333333  97.500000    10.0      0.0  1317.886179
# 9      11.166667  97.500000    10.0      0.0  1381.097561
# 10     11.166667  97.500000    10.0      0.0  1381.097561
# 11     12.333333  97.500000    10.0      0.0  1380.487805
# 12     12.333333  97.500000    10.0      0.0  1380.487805
# 13     12.000000  95.000000     8.5      0.0  1381.097561
# 14     12.000000  97.500000    10.0      0.0  1381.097561
# 15     12.000000  97.500000    10.0      0.0  1381.097561
# 16     12.000000  95.000000     8.5      0.0  1390.853659
# 17     14.000000  97.500000    10.0      0.0  1427.235772
# 18    311.000000  97.500000    10.0      0.0  1584.146341
# 19    481.500000  97.500000    10.0      0.0  1584.146341
# 20    542.333333  97.500000    10.0      0.0  1584.146341
# 21    542.833333  97.500000    10.0      0.0  1631.097561
# 22    542.833333  97.500000    10.0      0.0  1646.951220
# 23    539.333333  97.500000    10.0      0.0  1646.951220
# 24    542.833333  97.500000    10.0      0.0  1655.487805
# 25    539.333333  97.500000    10.0      0.0  1646.951220
# 26    539.333333  97.500000    10.0      0.0  1646.951220
# 27    541.833333  97.500000    10.0      0.0  1614.024390
# 28    541.833333  97.500000    10.0      0.0  1614.024390
# 29    459.000000  96.500000    10.0      0.0  1614.024390
# ..           ...        ...     ...      ...          ...
# 970  1074.666667  15.000000    10.0      0.0  1867.073171
# 971  1074.833333  15.000000    10.0      0.0  1870.121951
# 972  1074.666667  15.000000    10.0      0.0  1905.487805
# 973  1072.000000  17.666667    10.0      0.0  1943.902439
# 974  1072.000000  17.666667    10.0      0.0  1943.902439
# 975  1071.500000  16.333333    10.0      0.0  1943.902439
# 976  1071.500000  16.333333    10.0      0.0  1928.048780
# 977  1072.000000  16.333333    10.0      0.0  1943.902439
# 978  1071.500000  16.333333    10.0      0.0  1928.048780
# 979   860.000000  16.333333    10.0      0.0  1928.048780
# 980   659.500000  16.333333    10.0      0.0  1711.585366
# 981   544.666667  16.333333    10.0      0.0  1671.138211
# 982   544.666667  17.333333    10.0      0.0  1671.138211
# 983   543.333333  17.333333    10.0      0.0  1633.536585
# 984   543.333333  17.333333    10.0      0.0  1633.536585
# 985   271.000000  17.333333    10.0      0.0  1408.536585
# 986    14.000000  17.000000    10.0      0.0  1395.731707
# 987    14.000000  15.000000    10.0      0.0  1374.796748
# 988    14.000000  15.000000    10.0      0.0  1374.796748
# 989    16.500000  15.000000    10.0      0.0  1387.804878
# 990    18.000000  15.000000    10.0      0.0  1387.804878
# 991   117.500000  15.000000    10.0      0.0  1525.609756
# 992   435.000000  15.000000    10.0      0.0  1649.186992
# 993   542.666667  15.000000    10.0      0.0  1651.219512
# 994   542.666667  15.000000    10.0      0.0  1651.219512
# 995   542.500000  15.000000    10.0      0.0  1722.560976
# 996   542.500000  15.000000    10.0      0.0  1722.560976
# 997   545.000000  15.000000    10.0      0.0  1748.780488
# 998   832.500000  15.000000    10.0    810.0  1870.731707
# 999   846.000000  15.000000    10.0    870.0  1951.219512
#
# [1000 rows x 5 columns]

# %%
training_set.corr()
# Out:
#           CPU_user    net_TX    net_RX   disk_p2   Power12
# CPU_user  1.000000 -0.659445  0.022172  0.339696  0.947423
# net_TX   -0.659445  1.000000 -0.018293 -0.263045 -0.661148
# net_RX    0.022172 -0.018293  1.000000  0.016272  0.040189
# disk_p2   0.339696 -0.263045  0.016272  1.000000  0.496021
# Power12   0.947423 -0.661148  0.040189  0.496021  1.000000

# %%
fig = plotter.figure(figsize=(10, 10))
seaborn.heatmap(training_set.corr(), annot=True)
plotter.show()

# %% [markdown]
# The heatmap shows that the ```CPU_user``` and the ```power12``` features are highly correlated. The ```net_TX``` has a negative correlation. But that is likely true only for this particular application which is running on a single Pi.

# %% [markdown]
# The data will be scaled to between 0 and 1 for the input to the model.

# %%
training_set.head(15)
# Out:
#      CPU_user  net_TX  net_RX  disk_p2      Power12
# 0    6.500000    78.0     8.0      0.0  1330.487805
# 1   11.166667    97.5    10.0      0.0  1358.130081
# 2   11.666667    97.5    10.0      0.0  1374.390244
# 3   11.166667    97.5    10.0      0.0  1374.390244
# 4   11.166667    97.5    10.0      0.0  1358.130081
# 5   12.333333    97.5    10.0      0.0  1374.390244
# 6   12.333333    97.5    10.0      0.0  1380.487805
# 7   11.166667    97.5    10.0      0.0  1380.487805
# 8   12.333333    97.5    10.0      0.0  1317.886179
# 9   11.166667    97.5    10.0      0.0  1381.097561
# 10  11.166667    97.5    10.0      0.0  1381.097561
# 11  12.333333    97.5    10.0      0.0  1380.487805
# 12  12.333333    97.5    10.0      0.0  1380.487805
# 13  12.000000    95.0     8.5      0.0  1381.097561
# 14  12.000000    97.5    10.0      0.0  1381.097561

# %%
fig = plotter.figure(figsize=(25, 5))
plotter.plot(training_set["CPU_user"][:1000], label="CPU", linewidth=0.5)
plotter.plot(training_set["Power12"][:1000], label="Power", linewidth=0.5)
plotter.plot(training_set["net_TX"][:1000], label="TX", linewidth=0.5)
plotter.legend()
plotter.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
columns = training_set.columns

training_set = pandas.DataFrame(scaler.fit_transform(training_set), columns=columns)
training_set.describe()
# Out:
#            CPU_user        net_TX        net_RX       disk_p2       Power12
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.373789      0.184386      0.223214      0.069463      0.434587
# std        0.302933      0.135412      0.209057      0.145536      0.199491
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.011974      0.036855      0.056818      0.000000      0.223945
# 50%        0.458015      0.239558      0.056818      0.000000      0.458656
# 75%        0.488550      0.239558      0.481061      0.000000      0.537037
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
training_set.head(1000)
# Out:
#      CPU_user    net_TX    net_RX   disk_p2   Power12
# 0    0.005837  0.191646  0.045455  0.000000  0.138243
# 1    0.010028  0.239558  0.056818  0.000000  0.167528
# 2    0.010477  0.239558  0.056818  0.000000  0.184755
# 3    0.010028  0.239558  0.056818  0.000000  0.184755
# 4    0.010028  0.239558  0.056818  0.000000  0.167528
# 5    0.011076  0.239558  0.056818  0.000000  0.184755
# 6    0.011076  0.239558  0.056818  0.000000  0.191214
# 7    0.010028  0.239558  0.056818  0.000000  0.191214
# 8    0.011076  0.239558  0.056818  0.000000  0.124892
# 9    0.010028  0.239558  0.056818  0.000000  0.191860
# 10   0.010028  0.239558  0.056818  0.000000  0.191860
# 11   0.011076  0.239558  0.056818  0.000000  0.191214
# 12   0.011076  0.239558  0.056818  0.000000  0.191214
# 13   0.010777  0.233415  0.048295  0.000000  0.191860
# 14   0.010777  0.239558  0.056818  0.000000  0.191860
# 15   0.010777  0.239558  0.056818  0.000000  0.191860
# 16   0.010777  0.233415  0.048295  0.000000  0.202196
# 17   0.012573  0.239558  0.056818  0.000000  0.240741
# 18   0.279300  0.239558  0.056818  0.000000  0.406977
# 19   0.432420  0.239558  0.056818  0.000000  0.406977
# 20   0.487053  0.239558  0.056818  0.000000  0.406977
# 21   0.487502  0.239558  0.056818  0.000000  0.456718
# 22   0.487502  0.239558  0.056818  0.000000  0.473514
# 23   0.484359  0.239558  0.056818  0.000000  0.473514
# 24   0.487502  0.239558  0.056818  0.000000  0.482558
# 25   0.484359  0.239558  0.056818  0.000000  0.473514
# 26   0.484359  0.239558  0.056818  0.000000  0.473514
# 27   0.486604  0.239558  0.056818  0.000000  0.438630
# 28   0.486604  0.239558  0.056818  0.000000  0.438630
# 29   0.412214  0.237101  0.056818  0.000000  0.438630
# ..        ...       ...       ...       ...       ...
# 970  0.965125  0.036855  0.056818  0.000000  0.706718
# 971  0.965275  0.036855  0.056818  0.000000  0.709948
# 972  0.965125  0.036855  0.056818  0.000000  0.747416
# 973  0.962730  0.043407  0.056818  0.000000  0.788114
# 974  0.962730  0.043407  0.056818  0.000000  0.788114
# 975  0.962281  0.040131  0.056818  0.000000  0.788114
# 976  0.962281  0.040131  0.056818  0.000000  0.771318
# 977  0.962730  0.040131  0.056818  0.000000  0.788114
# 978  0.962281  0.040131  0.056818  0.000000  0.771318
# 979  0.772339  0.040131  0.056818  0.000000  0.771318
# 980  0.592277  0.040131  0.056818  0.000000  0.541990
# 981  0.489148  0.040131  0.056818  0.000000  0.499139
# 982  0.489148  0.042588  0.056818  0.000000  0.499139
# 983  0.487951  0.042588  0.056818  0.000000  0.459302
# 984  0.487951  0.042588  0.056818  0.000000  0.459302
# 985  0.243377  0.042588  0.056818  0.000000  0.220930
# 986  0.012573  0.041769  0.056818  0.000000  0.207364
# 987  0.012573  0.036855  0.056818  0.000000  0.185185
# 988  0.012573  0.036855  0.056818  0.000000  0.185185
# 989  0.014818  0.036855  0.056818  0.000000  0.198966
# 990  0.016165  0.036855  0.056818  0.000000  0.198966
# 991  0.105523  0.036855  0.056818  0.000000  0.344961
# 992  0.390660  0.036855  0.056818  0.000000  0.475883
# 993  0.487352  0.036855  0.056818  0.000000  0.478036
# 994  0.487352  0.036855  0.056818  0.000000  0.478036
# 995  0.487203  0.036855  0.056818  0.000000  0.553618
# 996  0.487203  0.036855  0.056818  0.000000  0.553618
# 997  0.489448  0.036855  0.056818  0.000000  0.581395
# 998  0.747643  0.036855  0.056818  0.251163  0.710594
# 999  0.759767  0.036855  0.056818  0.269767  0.795866
#
# [1000 rows x 5 columns]

# %%
fig = plotter.figure(figsize=(25, 5))
plotter.plot(training_set["CPU_user"], label="CPU", linewidth=0.5)
plotter.plot(training_set["Power12"], label="Power", linewidth=0.5)
plotter.plot(training_set["net_TX"], label="TX", linewidth=0.5)
plotter.legend()
plotter.show()

# %%
columns = validation_set.columns

validation_set = pandas.DataFrame(scaler.transform(validation_set.as_matrix()), columns=columns)
validation_set.describe()
# Out:
#            CPU_user        net_TX        net_RX       disk_p2       Power12
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.391217      0.173526      0.217059      0.071008      0.445192
# std        0.304066      0.136515      0.206919      0.145462      0.198274
# min        0.007185      0.029484      0.045455      0.000000      0.107881
# 25%        0.013022      0.036855      0.056818      0.000000      0.232989
# 50%        0.466397      0.237101      0.056818      0.000000      0.465116
# 75%        0.488849      0.239558      0.479167      0.000000      0.549096
# max        0.970962      0.529075      0.597538      0.933850      0.981912

# %%
fig = plotter.figure(figsize=(25, 5))
plotter.plot(validation_set["CPU_user"], label="CPU", linewidth=0.5)
plotter.plot(validation_set["Power12"], label="Power", linewidth=0.5)
plotter.plot(validation_set["net_TX"], label="TX", linewidth=0.5)
plotter.plot(validation_set["net_RX"], label="RX", linewidth=0.5)
plotter.plot(validation_set["disk_p2"], label="Disk", linewidth=0.5)
plotter.legend()
plotter.show()

# %%
fig = plotter.figure(figsize=(10, 10))
seaborn.heatmap(validation_set.corr(), annot=True)
plotter.show()

# %% [markdown]
# ### Define dataset handlers and helpers

# %%
import numpy

# %%
class DataLoader:
    """
        Defines data loader for seq2point model.
    """
    
    def __init__(self, X, y, window=5):
        self.X = X
        self.y = y
        self.window = window
        
    def __len__(self):
        return (self.X.shape[0]-(self.window + 1))
    
    def __getitem__(self, i):
        """
            Returns single batch of data in flat seq2point compatible format.
        """
        X = self.X[i: i+self.window, :]
        # y = self.y[i+int(self.window/2)]
        y = self.y[i+self.window]
        
        return (X, y)


class BatchLoader:
    """
        Creates batches from data provided by dataloader.
    """
    
    def __init__(self, dataloader, batch_size=32):
        self.dloader = dataloader
        self.batch_size = batch_size
        self.samples = list(range(len(self.dloader)))
        
    def __len__(self):
        return int(len(self.dloader)/self.batch_size) - 1
        
    def __getitem__(self, i):
        i = i*self.batch_size
        _samples = self.samples[i: i+self.batch_size]
        
        X=[]
        y=[]
        
        for j in range(len(_samples)):
            _X, _y = self.dloader[_samples[j]]
            X.append(_X.ravel())
            y.append(_y)
        
        return numpy.array(X), numpy.array(y)
    
class ConvBatchLoader:
    """
        Creates conv batches from data provided by dataloader.
    """
    
    def __init__(self, dataloader, batch_size=32):
        self.dloader = dataloader
        self.batch_size = batch_size
        self.samples = list(range(len(self.dloader)))
        
    def __len__(self):
        return int(len(self.dloader)/self.batch_size) - 1
        
    def __getitem__(self, i):
        i = i*self.batch_size
        _samples = self.samples[i: i+self.batch_size]
        
        X=[]
        y=[]
        
        for j in range(len(_samples)):
            _X, _y = self.dloader[_samples[j]]
            X.append(_X)
            y.append(_y)
        
        return numpy.array(X), numpy.array(y)

# %%
class DisaggDataLoader:
    """
        Defines data loader for disaggregation model.
    """
    
    def __init__(self, X, y, window=5):
        self.X = X
        self.y = y
        self.window = window
        
    def __len__(self):
        return (self.X.shape[0]-(self.window+1))
    
    def __getitem__(self, i):
        """
            Returns single batch of data in flat seq2point compatible format.
        """
        X = self.X[i: i+self.window]
        cpu_y = self.y.iloc[i+int(self.window/2)]["CPU_user"]
        tx_y = self.y.iloc[i+int(self.window/2)]["net_TX"]
        rx_y = self.y.iloc[i+int(self.window/2)]["net_RX"]
        disk_y = self.y.iloc[i+int(self.window/2)]["disk_p2"]
        
        return (X, {"cpu": cpu_y, "tx": tx_y, "rx": rx_y, "disk": disk_y})

# %%
class DisaggConvBatchLoader:
    """
        Creates conv batches from data provided by dataloader.
    """
    
    def __init__(self, dataloader, batch_size=32):
        self.dloader = dataloader
        self.batch_size = batch_size
        self.samples = list(range(len(self.dloader)))
        
    def __len__(self):
        return int(len(self.dloader)/self.batch_size) - 1
        
    def __getitem__(self, i):
        i = i*self.batch_size
        _samples = self.samples[i: i+self.batch_size]
        
        X=[]
        cpu_y=[]
        rx_y=[]
        tx_y=[]
        disk_y=[]
        
        for j in range(len(_samples)):
            _X, _y = self.dloader[_samples[j]]
            X.append(_X)
            cpu_y.append(_y["cpu"])
            rx_y.append(_y["rx"])
            tx_y.append(_y["tx"])
            disk_y.append(_y["disk"])
        
        return numpy.array(X), {"cpu": numpy.array(cpu_y), "tx": numpy.array(tx_y), "rx": numpy.array(rx_y), "disk": numpy.array(disk_y)}

# %% [markdown]
# The anomaly detection will be done using a thresholding function.

# %%
def run_thresholding(data):
        arr = pandas.Series(data)
        mean = 0
        count = 0
        outliers = numpy.zeros_like(arr)
        thres = numpy.zeros_like(arr)
        means = numpy.zeros_like(arr)
        cmeans = arr.expanding().mean()
        std = 0

        # Compute running stats

        m2 = 0
        for i in range(len(arr)):

            if i > 100 and arr[i] > (mean + 6.0 * std):
                outliers[i] = data[i]
                means[i] = mean
                thres[i] = mean + (6.0 * std)
                continue

            count = count + 1
            delta = arr[i] - mean

            mean = mean + (delta/count)
            means[i] = mean

            new_delta = arr[i] - mean
            m2 = m2 + delta * new_delta

            std = numpy.sqrt(m2 / count)

            thres[i] = mean + (6.0 * std)
            
        return thres, outliers

# %% [markdown]
# Define generator for keras models

# %%
def data_gen(loader):
    while 1:
        for i in range(len(loader)):
            yield loader[i]

# %% [markdown]
# Split the dataset into training, validation and testing set.

# %% [markdown]
# ### Aggregation Model

# %%
from keras.layers import Conv1D, Input, Dense, Flatten, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.utils import plot_model
from sklearn.metrics import mean_absolute_error
# Out:
# /home/adityas/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Prepare training and validation datasets for the aggregation model

# %% [markdown]
# Training Set

# %%
agg_train_y = training_set["Power12"]
agg_train_X = training_set.drop("Power12", axis=1)
agg_train_loader = ConvBatchLoader(dataloader=DataLoader(X=agg_train_X.as_matrix(), y=agg_train_y.as_matrix(), window=51), batch_size=64)
agg_train_generator = data_gen(agg_train_loader)

# %% [markdown]
# Validation Set

# %%
agg_val_y = validation_set["Power12"]
agg_val_X = validation_set.drop("Power12", axis=1)
agg_val_loader = ConvBatchLoader(dataloader=DataLoader(X=agg_val_X.as_matrix(), y=agg_val_y.as_matrix(), window=51), batch_size=5000)
agg_val_X, agg_val_y = agg_val_loader[0]

# %% [markdown]
# Define Aggregation model

# %%
agg_input = Input(shape=(51, 4))
agg_conv = Conv1D(kernel_size=10, filters=20, activation="relu")(agg_input)
agg_conv = Conv1D(kernel_size=10, filters=10, activation="relu")(agg_conv)
agg_conv = MaxPooling1D(pool_size=2)(agg_conv)
agg_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(agg_conv)
agg_conv = MaxPooling1D(pool_size=2)(agg_conv)
agg_conv = Conv1D(kernel_size=5, filters=10, activation="sigmoid")(agg_conv)
agg_flat = Flatten()(agg_conv)
agg_out = Dense(1, activation="sigmoid")(agg_flat)

# %%
agg_model = Model(inputs=agg_input, outputs=agg_out)
agg_model.compile(loss="mean_squared_error", optimizer="adam", metrics=["mean_absolute_error"])

# %% [markdown]
# Display aggregation model

# %%
plot_model(agg_model, to_file="agg_model.png", show_shapes=True)

# %% [markdown]
# <img src="agg_model.png">

# %%
estopper = EarlyStopping(monitor="val_loss", patience=10)
loss = agg_model.fit_generator(callbacks=[estopper], 
                               generator=agg_train_generator, 
                               validation_data=(agg_val_X, agg_val_y), 
                               shuffle=True, 
                               steps_per_epoch=1000, 
                               epochs=1000,
                               verbose=2)

fig = plotter.figure(figsize=(10, 10))
plotter.plot(loss.history["loss"], label="training loss")
plotter.plot(loss.history["val_loss"], label="validation loss")
plotter.legend()
plotter.show()
# Out:
# Epoch 1/1000
#  - 8s - loss: 0.0183 - mean_absolute_error: 0.1062 - val_loss: 0.0122 - val_mean_absolute_error: 0.0859
# Epoch 2/1000
#  - 5s - loss: 0.0102 - mean_absolute_error: 0.0766 - val_loss: 0.0090 - val_mean_absolute_error: 0.0724
# Epoch 3/1000
#  - 5s - loss: 0.0085 - mean_absolute_error: 0.0687 - val_loss: 0.0091 - val_mean_absolute_error: 0.0737
# Epoch 4/1000
#  - 5s - loss: 0.0077 - mean_absolute_error: 0.0651 - val_loss: 0.0072 - val_mean_absolute_error: 0.0623
# Epoch 5/1000
#  - 5s - loss: 0.0073 - mean_absolute_error: 0.0624 - val_loss: 0.0073 - val_mean_absolute_error: 0.0641
# Epoch 6/1000
#  - 5s - loss: 0.0070 - mean_absolute_error: 0.0611 - val_loss: 0.0073 - val_mean_absolute_error: 0.0652
# Epoch 7/1000
#  - 6s - loss: 0.0068 - mean_absolute_error: 0.0599 - val_loss: 0.0066 - val_mean_absolute_error: 0.0591
# Epoch 8/1000
#  - 5s - loss: 0.0067 - mean_absolute_error: 0.0592 - val_loss: 0.0069 - val_mean_absolute_error: 0.0605
# Epoch 9/1000
#  - 6s - loss: 0.0066 - mean_absolute_error: 0.0585 - val_loss: 0.0065 - val_mean_absolute_error: 0.0592
# Epoch 10/1000
#  - 6s - loss: 0.0064 - mean_absolute_error: 0.0575 - val_loss: 0.0070 - val_mean_absolute_error: 0.0612
# Epoch 11/1000
#  - 6s - loss: 0.0063 - mean_absolute_error: 0.0572 - val_loss: 0.0062 - val_mean_absolute_error: 0.0583
# Epoch 12/1000
#  - 6s - loss: 0.0062 - mean_absolute_error: 0.0565 - val_loss: 0.0062 - val_mean_absolute_error: 0.0579
# Epoch 13/1000
#  - 7s - loss: 0.0061 - mean_absolute_error: 0.0560 - val_loss: 0.0060 - val_mean_absolute_error: 0.0560
# Epoch 14/1000
#  - 6s - loss: 0.0060 - mean_absolute_error: 0.0555 - val_loss: 0.0060 - val_mean_absolute_error: 0.0557
# Epoch 15/1000
#  - 6s - loss: 0.0059 - mean_absolute_error: 0.0551 - val_loss: 0.0063 - val_mean_absolute_error: 0.0587
# Epoch 16/1000
#  - 6s - loss: 0.0058 - mean_absolute_error: 0.0546 - val_loss: 0.0058 - val_mean_absolute_error: 0.0558
# Epoch 17/1000
#  - 6s - loss: 0.0057 - mean_absolute_error: 0.0539 - val_loss: 0.0068 - val_mean_absolute_error: 0.0632
# Epoch 18/1000
#  - 7s - loss: 0.0057 - mean_absolute_error: 0.0537 - val_loss: 0.0060 - val_mean_absolute_error: 0.0578
# Epoch 19/1000
#  - 7s - loss: 0.0056 - mean_absolute_error: 0.0534 - val_loss: 0.0058 - val_mean_absolute_error: 0.0551
# Epoch 20/1000
#  - 6s - loss: 0.0055 - mean_absolute_error: 0.0531 - val_loss: 0.0057 - val_mean_absolute_error: 0.0548
# Epoch 21/1000
#  - 6s - loss: 0.0055 - mean_absolute_error: 0.0527 - val_loss: 0.0058 - val_mean_absolute_error: 0.0549
# Epoch 22/1000
#  - 6s - loss: 0.0054 - mean_absolute_error: 0.0524 - val_loss: 0.0056 - val_mean_absolute_error: 0.0548
# Epoch 23/1000
#  - 6s - loss: 0.0054 - mean_absolute_error: 0.0519 - val_loss: 0.0055 - val_mean_absolute_error: 0.0539
# Epoch 24/1000
#  - 6s - loss: 0.0052 - mean_absolute_error: 0.0512 - val_loss: 0.0055 - val_mean_absolute_error: 0.0541
# Epoch 25/1000
#  - 6s - loss: 0.0052 - mean_absolute_error: 0.0512 - val_loss: 0.0056 - val_mean_absolute_error: 0.0540
# Epoch 26/1000
#  - 6s - loss: 0.0051 - mean_absolute_error: 0.0507 - val_loss: 0.0054 - val_mean_absolute_error: 0.0531
# Epoch 27/1000
#  - 6s - loss: 0.0051 - mean_absolute_error: 0.0504 - val_loss: 0.0054 - val_mean_absolute_error: 0.0533
# Epoch 28/1000
#  - 8s - loss: 0.0051 - mean_absolute_error: 0.0501 - val_loss: 0.0055 - val_mean_absolute_error: 0.0533
# Epoch 29/1000
#  - 7s - loss: 0.0050 - mean_absolute_error: 0.0500 - val_loss: 0.0054 - val_mean_absolute_error: 0.0525
# Epoch 30/1000
#  - 7s - loss: 0.0049 - mean_absolute_error: 0.0495 - val_loss: 0.0053 - val_mean_absolute_error: 0.0528
# Epoch 31/1000
#  - 7s - loss: 0.0049 - mean_absolute_error: 0.0492 - val_loss: 0.0053 - val_mean_absolute_error: 0.0515
# Epoch 32/1000
#  - 7s - loss: 0.0049 - mean_absolute_error: 0.0492 - val_loss: 0.0056 - val_mean_absolute_error: 0.0537
# Epoch 33/1000
#  - 7s - loss: 0.0049 - mean_absolute_error: 0.0489 - val_loss: 0.0054 - val_mean_absolute_error: 0.0531
# Epoch 34/1000
#  - 7s - loss: 0.0048 - mean_absolute_error: 0.0487 - val_loss: 0.0055 - val_mean_absolute_error: 0.0529
# Epoch 35/1000
#  - 6s - loss: 0.0048 - mean_absolute_error: 0.0485 - val_loss: 0.0052 - val_mean_absolute_error: 0.0506
# Epoch 36/1000
#  - 6s - loss: 0.0048 - mean_absolute_error: 0.0484 - val_loss: 0.0053 - val_mean_absolute_error: 0.0520
# Epoch 37/1000
#  - 6s - loss: 0.0047 - mean_absolute_error: 0.0481 - val_loss: 0.0053 - val_mean_absolute_error: 0.0531
# Epoch 38/1000
#  - 6s - loss: 0.0047 - mean_absolute_error: 0.0479 - val_loss: 0.0052 - val_mean_absolute_error: 0.0502
# Epoch 39/1000
#  - 6s - loss: 0.0047 - mean_absolute_error: 0.0478 - val_loss: 0.0053 - val_mean_absolute_error: 0.0525
# Epoch 40/1000
#  - 6s - loss: 0.0047 - mean_absolute_error: 0.0477 - val_loss: 0.0050 - val_mean_absolute_error: 0.0500
# Epoch 41/1000
#  - 6s - loss: 0.0046 - mean_absolute_error: 0.0475 - val_loss: 0.0050 - val_mean_absolute_error: 0.0501
# Epoch 42/1000
#  - 6s - loss: 0.0046 - mean_absolute_error: 0.0476 - val_loss: 0.0050 - val_mean_absolute_error: 0.0498
# Epoch 43/1000
#  - 6s - loss: 0.0046 - mean_absolute_error: 0.0474 - val_loss: 0.0051 - val_mean_absolute_error: 0.0503
# Epoch 44/1000
#  - 6s - loss: 0.0046 - mean_absolute_error: 0.0473 - val_loss: 0.0050 - val_mean_absolute_error: 0.0501
# Epoch 45/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0471 - val_loss: 0.0053 - val_mean_absolute_error: 0.0511
# Epoch 46/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0470 - val_loss: 0.0052 - val_mean_absolute_error: 0.0507
# Epoch 47/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0469 - val_loss: 0.0049 - val_mean_absolute_error: 0.0491
# Epoch 48/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0468 - val_loss: 0.0052 - val_mean_absolute_error: 0.0517
# Epoch 49/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0468 - val_loss: 0.0052 - val_mean_absolute_error: 0.0514
# Epoch 50/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0466 - val_loss: 0.0049 - val_mean_absolute_error: 0.0497
# Epoch 51/1000
#  - 6s - loss: 0.0045 - mean_absolute_error: 0.0465 - val_loss: 0.0050 - val_mean_absolute_error: 0.0497
# Epoch 52/1000
#  - 6s - loss: 0.0044 - mean_absolute_error: 0.0463 - val_loss: 0.0060 - val_mean_absolute_error: 0.0555
# Epoch 53/1000
#  - 6s - loss: 0.0044 - mean_absolute_error: 0.0464 - val_loss: 0.0049 - val_mean_absolute_error: 0.0493
# Epoch 54/1000
#  - 7s - loss: 0.0044 - mean_absolute_error: 0.0461 - val_loss: 0.0050 - val_mean_absolute_error: 0.0492
# Epoch 55/1000
#  - 6s - loss: 0.0044 - mean_absolute_error: 0.0460 - val_loss: 0.0050 - val_mean_absolute_error: 0.0484
# Epoch 56/1000
#  - 5s - loss: 0.0044 - mean_absolute_error: 0.0461 - val_loss: 0.0050 - val_mean_absolute_error: 0.0492
# Epoch 57/1000
#  - 5s - loss: 0.0044 - mean_absolute_error: 0.0459 - val_loss: 0.0052 - val_mean_absolute_error: 0.0511
# Epoch 58/1000
#  - 6s - loss: 0.0044 - mean_absolute_error: 0.0460 - val_loss: 0.0050 - val_mean_absolute_error: 0.0499
# Epoch 59/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0456 - val_loss: 0.0050 - val_mean_absolute_error: 0.0486
# Epoch 60/1000
#  - 5s - loss: 0.0044 - mean_absolute_error: 0.0458 - val_loss: 0.0049 - val_mean_absolute_error: 0.0491
# Epoch 61/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0456 - val_loss: 0.0049 - val_mean_absolute_error: 0.0486
# Epoch 62/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0454 - val_loss: 0.0050 - val_mean_absolute_error: 0.0485
# Epoch 63/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0454 - val_loss: 0.0051 - val_mean_absolute_error: 0.0499
# Epoch 64/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0453 - val_loss: 0.0051 - val_mean_absolute_error: 0.0499
# Epoch 65/1000
#  - 6s - loss: 0.0043 - mean_absolute_error: 0.0453 - val_loss: 0.0058 - val_mean_absolute_error: 0.0544
# Epoch 66/1000
#  - 6s - loss: 0.0042 - mean_absolute_error: 0.0451 - val_loss: 0.0049 - val_mean_absolute_error: 0.0483
# Epoch 67/1000
#  - 5s - loss: 0.0042 - mean_absolute_error: 0.0451 - val_loss: 0.0049 - val_mean_absolute_error: 0.0485
# Epoch 68/1000
#  - 6s - loss: 0.0042 - mean_absolute_error: 0.0451 - val_loss: 0.0049 - val_mean_absolute_error: 0.0490
# Epoch 69/1000
#  - 6s - loss: 0.0042 - mean_absolute_error: 0.0449 - val_loss: 0.0051 - val_mean_absolute_error: 0.0493
# Epoch 70/1000
#  - 6s - loss: 0.0042 - mean_absolute_error: 0.0449 - val_loss: 0.0053 - val_mean_absolute_error: 0.0518

# %%
agg_model.evaluate(x=agg_val_X, y=agg_val_y, verbose=1)
# Out:
# 5000/5000 [==============================] - 0s 37us/step
# [0.0053389694644138215, 0.05180797090530395]

# %% [markdown]
# ### Testing aggregation model

# %%
prediction = agg_model.predict(agg_val_X)
print("predictions")
fig = plotter.figure(figsize=(25,5))
plotter.plot(agg_val_y[2000: 3000], linewidth=0.5, label="True")
plotter.plot(prediction[2000: 3000], linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()
# Out:
# predictions

# %% [markdown]
# ### Disaggregation model

# %% [markdown]
# Prepare training and validation sets for disaggregation model

# %% [markdown]
# Training set

# %%
disagg_train_X = training_set["Power12"]
disagg_train_y = training_set.drop("Power12", axis=1)
disagg_train_loader = DisaggConvBatchLoader(dataloader=DisaggDataLoader(X=disagg_train_X.as_matrix()[:, numpy.newaxis], 
                                                                        y=disagg_train_y, 
                                                                        window=51), 
                                            batch_size=64)

disagg_train_generator = data_gen(disagg_train_loader)

# %% [markdown]
# Validation set

# %%
disagg_val_X = validation_set["Power12"]
disagg_val_y = validation_set.drop("Power12", axis=1)
disagg_val_loader = DisaggConvBatchLoader(dataloader=DisaggDataLoader(X=disagg_val_X.as_matrix()[:, numpy.newaxis],
                                                                      y=disagg_val_y, 
                                                                      window=51), 
                                          batch_size=5000)

disagg_val_X, disagg_val_y = disagg_val_loader[0]

# %% [markdown]
# Define disaggregation model

# %%
disagg_input = Input(shape=(51, 1))
disaggconv = Conv1D(kernel_size=10, filters=40, activation="relu")(disagg_input)
disaggconv = MaxPooling1D(pool_size=2)(disaggconv)
disaggconv = Conv1D(kernel_size=10, filters=40, activation="relu")(disaggconv)

#CPU
disagg_cpu_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disaggconv)
disagg_cpu_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disagg_cpu_conv)
disagg_cpu_flat = Flatten()(disagg_cpu_conv)
disagg_cpu_out = Dense(1, activation="sigmoid", name="cpu")(disagg_cpu_flat)

#TX
disagg_tx_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disaggconv)
disagg_tx_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disagg_tx_conv)
disagg_tx_flat = Flatten()(disagg_tx_conv)
disagg_tx_out = Dense(1, activation="sigmoid", name="tx")(disagg_tx_flat)

#RX
disagg_rx_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disaggconv)
disagg_rx_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disagg_rx_conv)
disagg_rx_flat = Flatten()(disagg_rx_conv)
disagg_rx_out = Dense(1, activation="sigmoid", name="rx")(disagg_rx_flat)

#Disk
disagg_disk_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disaggconv)
disagg_disk_conv = Conv1D(kernel_size=5, filters=10, activation="relu")(disagg_disk_conv)
disagg_disk_flat = Flatten()(disagg_disk_conv)
disagg_disk_out = Dense(1, activation="sigmoid", name="disk")(disagg_disk_flat)

# %%
disagg_model = Model(inputs=disagg_input, outputs=[disagg_cpu_out, 
                                                   disagg_tx_out, 
                                                   disagg_rx_out, 
                                                   disagg_disk_out])
disagg_model.compile(loss="mean_squared_error", optimizer="adam", metrics=["mean_absolute_error"])

# %% [markdown]
# Display model

# %%
plot_model(disagg_model, to_file="disagg_model.png", show_shapes=True)

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(disagg_model).create(prog='dot', format='svg'))

# %% [markdown]
# Train model

# %%
estopper = EarlyStopping(monitor="val_loss", patience=10)
loss = disagg_model.fit_generator(callbacks=[estopper], 
                                  generator=disagg_train_generator, 
                                  validation_data=(disagg_val_X, disagg_val_y), 
                                  shuffle=True, 
                                  steps_per_epoch=1000, 
                                  epochs=1000,
                                  verbose=2)

fig = plotter.figure(figsize=(10, 10))
plotter.plot(loss.history["loss"], label="training loss")
plotter.plot(loss.history["val_loss"], label="validation loss")
plotter.legend()
plotter.show()
# Out:
# Epoch 1/1000
#  - 27s - loss: 0.0937 - cpu_loss: 0.0236 - tx_loss: 0.0070 - rx_loss: 0.0472 - disk_loss: 0.0159 - cpu_mean_absolute_error: 0.1107 - tx_mean_absolute_error: 0.0643 - rx_mean_absolute_error: 0.2045 - disk_mean_absolute_error: 0.0781 - val_loss: 0.0667 - val_cpu_loss: 0.0084 - val_tx_loss: 0.0048 - val_rx_loss: 0.0450 - val_disk_loss: 0.0086 - val_cpu_mean_absolute_error: 0.0732 - val_tx_mean_absolute_error: 0.0565 - val_rx_mean_absolute_error: 0.2064 - val_disk_mean_absolute_error: 0.0531
# Epoch 2/1000
#  - 28s - loss: 0.0637 - cpu_loss: 0.0068 - tx_loss: 0.0039 - rx_loss: 0.0451 - disk_loss: 0.0078 - cpu_mean_absolute_error: 0.0603 - tx_mean_absolute_error: 0.0484 - rx_mean_absolute_error: 0.2042 - disk_mean_absolute_error: 0.0517 - val_loss: 0.0618 - val_cpu_loss: 0.0077 - val_tx_loss: 0.0037 - val_rx_loss: 0.0440 - val_disk_loss: 0.0065 - val_cpu_mean_absolute_error: 0.0675 - val_tx_mean_absolute_error: 0.0471 - val_rx_mean_absolute_error: 0.2074 - val_disk_mean_absolute_error: 0.0479
# Epoch 3/1000
#  - 26s - loss: 0.0600 - cpu_loss: 0.0054 - tx_loss: 0.0033 - rx_loss: 0.0449 - disk_loss: 0.0064 - cpu_mean_absolute_error: 0.0504 - tx_mean_absolute_error: 0.0416 - rx_mean_absolute_error: 0.2039 - disk_mean_absolute_error: 0.0437 - val_loss: 0.0569 - val_cpu_loss: 0.0049 - val_tx_loss: 0.0030 - val_rx_loss: 0.0438 - val_disk_loss: 0.0052 - val_cpu_mean_absolute_error: 0.0449 - val_tx_mean_absolute_error: 0.0378 - val_rx_mean_absolute_error: 0.2078 - val_disk_mean_absolute_error: 0.0387
# Epoch 4/1000
#  - 25s - loss: 0.0579 - cpu_loss: 0.0045 - tx_loss: 0.0031 - rx_loss: 0.0446 - disk_loss: 0.0057 - cpu_mean_absolute_error: 0.0443 - tx_mean_absolute_error: 0.0386 - rx_mean_absolute_error: 0.2028 - disk_mean_absolute_error: 0.0394 - val_loss: 0.0573 - val_cpu_loss: 0.0060 - val_tx_loss: 0.0033 - val_rx_loss: 0.0436 - val_disk_loss: 0.0045 - val_cpu_mean_absolute_error: 0.0523 - val_tx_mean_absolute_error: 0.0401 - val_rx_mean_absolute_error: 0.2039 - val_disk_mean_absolute_error: 0.0370
# Epoch 5/1000
#  - 26s - loss: 0.0567 - cpu_loss: 0.0041 - tx_loss: 0.0030 - rx_loss: 0.0444 - disk_loss: 0.0051 - cpu_mean_absolute_error: 0.0400 - tx_mean_absolute_error: 0.0368 - rx_mean_absolute_error: 0.2030 - disk_mean_absolute_error: 0.0366 - val_loss: 0.0554 - val_cpu_loss: 0.0036 - val_tx_loss: 0.0030 - val_rx_loss: 0.0446 - val_disk_loss: 0.0042 - val_cpu_mean_absolute_error: 0.0379 - val_tx_mean_absolute_error: 0.0336 - val_rx_mean_absolute_error: 0.2004 - val_disk_mean_absolute_error: 0.0313
# Epoch 6/1000
#  - 26s - loss: 0.0555 - cpu_loss: 0.0037 - tx_loss: 0.0029 - rx_loss: 0.0442 - disk_loss: 0.0047 - cpu_mean_absolute_error: 0.0373 - tx_mean_absolute_error: 0.0358 - rx_mean_absolute_error: 0.2029 - disk_mean_absolute_error: 0.0342 - val_loss: 0.0536 - val_cpu_loss: 0.0035 - val_tx_loss: 0.0031 - val_rx_loss: 0.0435 - val_disk_loss: 0.0035 - val_cpu_mean_absolute_error: 0.0353 - val_tx_mean_absolute_error: 0.0341 - val_rx_mean_absolute_error: 0.2028 - val_disk_mean_absolute_error: 0.0276
# Epoch 7/1000
#  - 25s - loss: 0.0553 - cpu_loss: 0.0035 - tx_loss: 0.0028 - rx_loss: 0.0447 - disk_loss: 0.0044 - cpu_mean_absolute_error: 0.0353 - tx_mean_absolute_error: 0.0349 - rx_mean_absolute_error: 0.2036 - disk_mean_absolute_error: 0.0322 - val_loss: 0.0536 - val_cpu_loss: 0.0032 - val_tx_loss: 0.0028 - val_rx_loss: 0.0442 - val_disk_loss: 0.0034 - val_cpu_mean_absolute_error: 0.0342 - val_tx_mean_absolute_error: 0.0320 - val_rx_mean_absolute_error: 0.2038 - val_disk_mean_absolute_error: 0.0302
# Epoch 8/1000
#  - 26s - loss: 0.0542 - cpu_loss: 0.0032 - tx_loss: 0.0029 - rx_loss: 0.0441 - disk_loss: 0.0040 - cpu_mean_absolute_error: 0.0335 - tx_mean_absolute_error: 0.0344 - rx_mean_absolute_error: 0.2026 - disk_mean_absolute_error: 0.0297 - val_loss: 0.0577 - val_cpu_loss: 0.0032 - val_tx_loss: 0.0035 - val_rx_loss: 0.0463 - val_disk_loss: 0.0048 - val_cpu_mean_absolute_error: 0.0345 - val_tx_mean_absolute_error: 0.0453 - val_rx_mean_absolute_error: 0.2006 - val_disk_mean_absolute_error: 0.0385
# Epoch 9/1000
#  - 26s - loss: 0.0535 - cpu_loss: 0.0030 - tx_loss: 0.0028 - rx_loss: 0.0441 - disk_loss: 0.0036 - cpu_mean_absolute_error: 0.0322 - tx_mean_absolute_error: 0.0339 - rx_mean_absolute_error: 0.2027 - disk_mean_absolute_error: 0.0277 - val_loss: 0.0534 - val_cpu_loss: 0.0038 - val_tx_loss: 0.0030 - val_rx_loss: 0.0437 - val_disk_loss: 0.0029 - val_cpu_mean_absolute_error: 0.0351 - val_tx_mean_absolute_error: 0.0401 - val_rx_mean_absolute_error: 0.2040 - val_disk_mean_absolute_error: 0.0243
# Epoch 10/1000
#  - 28s - loss: 0.0534 - cpu_loss: 0.0029 - tx_loss: 0.0027 - rx_loss: 0.0443 - disk_loss: 0.0035 - cpu_mean_absolute_error: 0.0314 - tx_mean_absolute_error: 0.0330 - rx_mean_absolute_error: 0.2032 - disk_mean_absolute_error: 0.0262 - val_loss: 0.0520 - val_cpu_loss: 0.0025 - val_tx_loss: 0.0025 - val_rx_loss: 0.0440 - val_disk_loss: 0.0029 - val_cpu_mean_absolute_error: 0.0291 - val_tx_mean_absolute_error: 0.0301 - val_rx_mean_absolute_error: 0.2082 - val_disk_mean_absolute_error: 0.0203
# Epoch 11/1000
#  - 28s - loss: 0.0530 - cpu_loss: 0.0029 - tx_loss: 0.0026 - rx_loss: 0.0442 - disk_loss: 0.0034 - cpu_mean_absolute_error: 0.0311 - tx_mean_absolute_error: 0.0323 - rx_mean_absolute_error: 0.2026 - disk_mean_absolute_error: 0.0257 - val_loss: 0.0518 - val_cpu_loss: 0.0026 - val_tx_loss: 0.0026 - val_rx_loss: 0.0439 - val_disk_loss: 0.0027 - val_cpu_mean_absolute_error: 0.0302 - val_tx_mean_absolute_error: 0.0315 - val_rx_mean_absolute_error: 0.2016 - val_disk_mean_absolute_error: 0.0201
# Epoch 12/1000
#  - 26s - loss: 0.0528 - cpu_loss: 0.0028 - tx_loss: 0.0027 - rx_loss: 0.0441 - disk_loss: 0.0032 - cpu_mean_absolute_error: 0.0304 - tx_mean_absolute_error: 0.0327 - rx_mean_absolute_error: 0.2027 - disk_mean_absolute_error: 0.0243 - val_loss: 0.0519 - val_cpu_loss: 0.0029 - val_tx_loss: 0.0026 - val_rx_loss: 0.0440 - val_disk_loss: 0.0025 - val_cpu_mean_absolute_error: 0.0309 - val_tx_mean_absolute_error: 0.0323 - val_rx_mean_absolute_error: 0.2031 - val_disk_mean_absolute_error: 0.0233
# Epoch 13/1000
#  - 27s - loss: 0.0520 - cpu_loss: 0.0027 - tx_loss: 0.0027 - rx_loss: 0.0438 - disk_loss: 0.0029 - cpu_mean_absolute_error: 0.0300 - tx_mean_absolute_error: 0.0324 - rx_mean_absolute_error: 0.2021 - disk_mean_absolute_error: 0.0231 - val_loss: 0.0510 - val_cpu_loss: 0.0026 - val_tx_loss: 0.0025 - val_rx_loss: 0.0436 - val_disk_loss: 0.0022 - val_cpu_mean_absolute_error: 0.0316 - val_tx_mean_absolute_error: 0.0301 - val_rx_mean_absolute_error: 0.2030 - val_disk_mean_absolute_error: 0.0192
# Epoch 14/1000
#  - 27s - loss: 0.0524 - cpu_loss: 0.0027 - tx_loss: 0.0026 - rx_loss: 0.0444 - disk_loss: 0.0028 - cpu_mean_absolute_error: 0.0297 - tx_mean_absolute_error: 0.0317 - rx_mean_absolute_error: 0.2034 - disk_mean_absolute_error: 0.0225 - val_loss: 0.0526 - val_cpu_loss: 0.0025 - val_tx_loss: 0.0025 - val_rx_loss: 0.0455 - val_disk_loss: 0.0021 - val_cpu_mean_absolute_error: 0.0293 - val_tx_mean_absolute_error: 0.0299 - val_rx_mean_absolute_error: 0.2000 - val_disk_mean_absolute_error: 0.0218
# Epoch 15/1000
#  - 25s - loss: 0.0517 - cpu_loss: 0.0027 - tx_loss: 0.0026 - rx_loss: 0.0438 - disk_loss: 0.0026 - cpu_mean_absolute_error: 0.0296 - tx_mean_absolute_error: 0.0315 - rx_mean_absolute_error: 0.2020 - disk_mean_absolute_error: 0.0216 - val_loss: 0.0536 - val_cpu_loss: 0.0023 - val_tx_loss: 0.0035 - val_rx_loss: 0.0458 - val_disk_loss: 0.0019 - val_cpu_mean_absolute_error: 0.0280 - val_tx_mean_absolute_error: 0.0365 - val_rx_mean_absolute_error: 0.2004 - val_disk_mean_absolute_error: 0.0175
# Epoch 16/1000
#  - 25s - loss: 0.0513 - cpu_loss: 0.0025 - tx_loss: 0.0026 - rx_loss: 0.0439 - disk_loss: 0.0023 - cpu_mean_absolute_error: 0.0288 - tx_mean_absolute_error: 0.0317 - rx_mean_absolute_error: 0.2022 - disk_mean_absolute_error: 0.0199 - val_loss: 0.0508 - val_cpu_loss: 0.0023 - val_tx_loss: 0.0031 - val_rx_loss: 0.0438 - val_disk_loss: 0.0017 - val_cpu_mean_absolute_error: 0.0265 - val_tx_mean_absolute_error: 0.0356 - val_rx_mean_absolute_error: 0.2047 - val_disk_mean_absolute_error: 0.0162
# Epoch 17/1000
#  - 25s - loss: 0.0511 - cpu_loss: 0.0025 - tx_loss: 0.0025 - rx_loss: 0.0439 - disk_loss: 0.0022 - cpu_mean_absolute_error: 0.0285 - tx_mean_absolute_error: 0.0312 - rx_mean_absolute_error: 0.2024 - disk_mean_absolute_error: 0.0190 - val_loss: 0.0509 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0028 - val_rx_loss: 0.0440 - val_disk_loss: 0.0019 - val_cpu_mean_absolute_error: 0.0271 - val_tx_mean_absolute_error: 0.0317 - val_rx_mean_absolute_error: 0.2080 - val_disk_mean_absolute_error: 0.0167
# Epoch 18/1000
#  - 25s - loss: 0.0510 - cpu_loss: 0.0025 - tx_loss: 0.0025 - rx_loss: 0.0439 - disk_loss: 0.0021 - cpu_mean_absolute_error: 0.0286 - tx_mean_absolute_error: 0.0307 - rx_mean_absolute_error: 0.2024 - disk_mean_absolute_error: 0.0185 - val_loss: 0.0508 - val_cpu_loss: 0.0023 - val_tx_loss: 0.0026 - val_rx_loss: 0.0440 - val_disk_loss: 0.0020 - val_cpu_mean_absolute_error: 0.0273 - val_tx_mean_absolute_error: 0.0311 - val_rx_mean_absolute_error: 0.2035 - val_disk_mean_absolute_error: 0.0176
# Epoch 19/1000
#  - 25s - loss: 0.0509 - cpu_loss: 0.0025 - tx_loss: 0.0025 - rx_loss: 0.0438 - disk_loss: 0.0021 - cpu_mean_absolute_error: 0.0285 - tx_mean_absolute_error: 0.0309 - rx_mean_absolute_error: 0.2021 - disk_mean_absolute_error: 0.0183 - val_loss: 0.0515 - val_cpu_loss: 0.0025 - val_tx_loss: 0.0024 - val_rx_loss: 0.0443 - val_disk_loss: 0.0023 - val_cpu_mean_absolute_error: 0.0284 - val_tx_mean_absolute_error: 0.0298 - val_rx_mean_absolute_error: 0.2042 - val_disk_mean_absolute_error: 0.0198
# Epoch 20/1000
#  - 25s - loss: 0.0503 - cpu_loss: 0.0024 - tx_loss: 0.0025 - rx_loss: 0.0435 - disk_loss: 0.0018 - cpu_mean_absolute_error: 0.0280 - tx_mean_absolute_error: 0.0305 - rx_mean_absolute_error: 0.2016 - disk_mean_absolute_error: 0.0171 - val_loss: 0.0505 - val_cpu_loss: 0.0024 - val_tx_loss: 0.0024 - val_rx_loss: 0.0436 - val_disk_loss: 0.0021 - val_cpu_mean_absolute_error: 0.0282 - val_tx_mean_absolute_error: 0.0296 - val_rx_mean_absolute_error: 0.2025 - val_disk_mean_absolute_error: 0.0183
# Epoch 21/1000
#  - 25s - loss: 0.0508 - cpu_loss: 0.0024 - tx_loss: 0.0024 - rx_loss: 0.0441 - disk_loss: 0.0018 - cpu_mean_absolute_error: 0.0279 - tx_mean_absolute_error: 0.0298 - rx_mean_absolute_error: 0.2031 - disk_mean_absolute_error: 0.0166 - val_loss: 0.0518 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0025 - val_rx_loss: 0.0453 - val_disk_loss: 0.0018 - val_cpu_mean_absolute_error: 0.0272 - val_tx_mean_absolute_error: 0.0283 - val_rx_mean_absolute_error: 0.1995 - val_disk_mean_absolute_error: 0.0154
# Epoch 22/1000
#  - 25s - loss: 0.0502 - cpu_loss: 0.0023 - tx_loss: 0.0024 - rx_loss: 0.0436 - disk_loss: 0.0018 - cpu_mean_absolute_error: 0.0278 - tx_mean_absolute_error: 0.0300 - rx_mean_absolute_error: 0.2016 - disk_mean_absolute_error: 0.0162 - val_loss: 0.0532 - val_cpu_loss: 0.0032 - val_tx_loss: 0.0026 - val_rx_loss: 0.0452 - val_disk_loss: 0.0022 - val_cpu_mean_absolute_error: 0.0323 - val_tx_mean_absolute_error: 0.0322 - val_rx_mean_absolute_error: 0.2021 - val_disk_mean_absolute_error: 0.0192
# Epoch 23/1000
#  - 29s - loss: 0.0500 - cpu_loss: 0.0023 - tx_loss: 0.0024 - rx_loss: 0.0435 - disk_loss: 0.0017 - cpu_mean_absolute_error: 0.0275 - tx_mean_absolute_error: 0.0301 - rx_mean_absolute_error: 0.2014 - disk_mean_absolute_error: 0.0157 - val_loss: 0.0500 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0024 - val_rx_loss: 0.0436 - val_disk_loss: 0.0018 - val_cpu_mean_absolute_error: 0.0257 - val_tx_mean_absolute_error: 0.0307 - val_rx_mean_absolute_error: 0.2020 - val_disk_mean_absolute_error: 0.0136
# Epoch 24/1000
#  - 27s - loss: 0.0499 - cpu_loss: 0.0023 - tx_loss: 0.0024 - rx_loss: 0.0436 - disk_loss: 0.0016 - cpu_mean_absolute_error: 0.0273 - tx_mean_absolute_error: 0.0298 - rx_mean_absolute_error: 0.2015 - disk_mean_absolute_error: 0.0150 - val_loss: 0.0498 - val_cpu_loss: 0.0023 - val_tx_loss: 0.0024 - val_rx_loss: 0.0434 - val_disk_loss: 0.0018 - val_cpu_mean_absolute_error: 0.0274 - val_tx_mean_absolute_error: 0.0299 - val_rx_mean_absolute_error: 0.2045 - val_disk_mean_absolute_error: 0.0164
# Epoch 25/1000
#  - 28s - loss: 0.0500 - cpu_loss: 0.0023 - tx_loss: 0.0023 - rx_loss: 0.0439 - disk_loss: 0.0016 - cpu_mean_absolute_error: 0.0276 - tx_mean_absolute_error: 0.0290 - rx_mean_absolute_error: 0.2022 - disk_mean_absolute_error: 0.0151 - val_loss: 0.0509 - val_cpu_loss: 0.0021 - val_tx_loss: 0.0026 - val_rx_loss: 0.0441 - val_disk_loss: 0.0021 - val_cpu_mean_absolute_error: 0.0267 - val_tx_mean_absolute_error: 0.0308 - val_rx_mean_absolute_error: 0.2035 - val_disk_mean_absolute_error: 0.0186
# Epoch 26/1000
#  - 28s - loss: 0.0497 - cpu_loss: 0.0023 - tx_loss: 0.0024 - rx_loss: 0.0435 - disk_loss: 0.0016 - cpu_mean_absolute_error: 0.0274 - tx_mean_absolute_error: 0.0295 - rx_mean_absolute_error: 0.2012 - disk_mean_absolute_error: 0.0150 - val_loss: 0.0518 - val_cpu_loss: 0.0024 - val_tx_loss: 0.0024 - val_rx_loss: 0.0443 - val_disk_loss: 0.0026 - val_cpu_mean_absolute_error: 0.0282 - val_tx_mean_absolute_error: 0.0318 - val_rx_mean_absolute_error: 0.2042 - val_disk_mean_absolute_error: 0.0216
# Epoch 27/1000
#  - 28s - loss: 0.0494 - cpu_loss: 0.0023 - tx_loss: 0.0023 - rx_loss: 0.0432 - disk_loss: 0.0016 - cpu_mean_absolute_error: 0.0274 - tx_mean_absolute_error: 0.0291 - rx_mean_absolute_error: 0.2005 - disk_mean_absolute_error: 0.0150 - val_loss: 0.0510 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0026 - val_rx_loss: 0.0444 - val_disk_loss: 0.0018 - val_cpu_mean_absolute_error: 0.0286 - val_tx_mean_absolute_error: 0.0289 - val_rx_mean_absolute_error: 0.2024 - val_disk_mean_absolute_error: 0.0136
# Epoch 28/1000
#  - 27s - loss: 0.0498 - cpu_loss: 0.0022 - tx_loss: 0.0022 - rx_loss: 0.0438 - disk_loss: 0.0015 - cpu_mean_absolute_error: 0.0272 - tx_mean_absolute_error: 0.0286 - rx_mean_absolute_error: 0.2021 - disk_mean_absolute_error: 0.0144 - val_loss: 0.0514 - val_cpu_loss: 0.0023 - val_tx_loss: 0.0024 - val_rx_loss: 0.0452 - val_disk_loss: 0.0016 - val_cpu_mean_absolute_error: 0.0269 - val_tx_mean_absolute_error: 0.0295 - val_rx_mean_absolute_error: 0.2011 - val_disk_mean_absolute_error: 0.0137
# Epoch 29/1000
#  - 25s - loss: 0.0493 - cpu_loss: 0.0022 - tx_loss: 0.0023 - rx_loss: 0.0433 - disk_loss: 0.0015 - cpu_mean_absolute_error: 0.0271 - tx_mean_absolute_error: 0.0285 - rx_mean_absolute_error: 0.2005 - disk_mean_absolute_error: 0.0144 - val_loss: 0.0509 - val_cpu_loss: 0.0021 - val_tx_loss: 0.0026 - val_rx_loss: 0.0445 - val_disk_loss: 0.0017 - val_cpu_mean_absolute_error: 0.0270 - val_tx_mean_absolute_error: 0.0348 - val_rx_mean_absolute_error: 0.2047 - val_disk_mean_absolute_error: 0.0149
# Epoch 30/1000
#  - 25s - loss: 0.0489 - cpu_loss: 0.0021 - tx_loss: 0.0023 - rx_loss: 0.0431 - disk_loss: 0.0014 - cpu_mean_absolute_error: 0.0267 - tx_mean_absolute_error: 0.0288 - rx_mean_absolute_error: 0.1997 - disk_mean_absolute_error: 0.0139 - val_loss: 0.0499 - val_cpu_loss: 0.0021 - val_tx_loss: 0.0024 - val_rx_loss: 0.0436 - val_disk_loss: 0.0018 - val_cpu_mean_absolute_error: 0.0262 - val_tx_mean_absolute_error: 0.0301 - val_rx_mean_absolute_error: 0.2036 - val_disk_mean_absolute_error: 0.0136
# Epoch 31/1000
#  - 27s - loss: 0.0488 - cpu_loss: 0.0022 - tx_loss: 0.0022 - rx_loss: 0.0430 - disk_loss: 0.0014 - cpu_mean_absolute_error: 0.0268 - tx_mean_absolute_error: 0.0288 - rx_mean_absolute_error: 0.1996 - disk_mean_absolute_error: 0.0136 - val_loss: 0.0501 - val_cpu_loss: 0.0024 - val_tx_loss: 0.0024 - val_rx_loss: 0.0432 - val_disk_loss: 0.0022 - val_cpu_mean_absolute_error: 0.0298 - val_tx_mean_absolute_error: 0.0287 - val_rx_mean_absolute_error: 0.2027 - val_disk_mean_absolute_error: 0.0185
# Epoch 32/1000
#  - 26s - loss: 0.0493 - cpu_loss: 0.0022 - tx_loss: 0.0022 - rx_loss: 0.0435 - disk_loss: 0.0014 - cpu_mean_absolute_error: 0.0270 - tx_mean_absolute_error: 0.0281 - rx_mean_absolute_error: 0.2007 - disk_mean_absolute_error: 0.0138 - val_loss: 0.0508 - val_cpu_loss: 0.0021 - val_tx_loss: 0.0026 - val_rx_loss: 0.0442 - val_disk_loss: 0.0020 - val_cpu_mean_absolute_error: 0.0271 - val_tx_mean_absolute_error: 0.0310 - val_rx_mean_absolute_error: 0.2021 - val_disk_mean_absolute_error: 0.0151
# Epoch 33/1000
#  - 26s - loss: 0.0488 - cpu_loss: 0.0021 - tx_loss: 0.0023 - rx_loss: 0.0430 - disk_loss: 0.0014 - cpu_mean_absolute_error: 0.0268 - tx_mean_absolute_error: 0.0286 - rx_mean_absolute_error: 0.1992 - disk_mean_absolute_error: 0.0135 - val_loss: 0.0504 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0024 - val_rx_loss: 0.0444 - val_disk_loss: 0.0015 - val_cpu_mean_absolute_error: 0.0264 - val_tx_mean_absolute_error: 0.0268 - val_rx_mean_absolute_error: 0.2062 - val_disk_mean_absolute_error: 0.0137
# Epoch 34/1000
#  - 28s - loss: 0.0482 - cpu_loss: 0.0021 - tx_loss: 0.0022 - rx_loss: 0.0425 - disk_loss: 0.0013 - cpu_mean_absolute_error: 0.0264 - tx_mean_absolute_error: 0.0286 - rx_mean_absolute_error: 0.1979 - disk_mean_absolute_error: 0.0134 - val_loss: 0.0516 - val_cpu_loss: 0.0022 - val_tx_loss: 0.0025 - val_rx_loss: 0.0450 - val_disk_loss: 0.0019 - val_cpu_mean_absolute_error: 0.0267 - val_tx_mean_absolute_error: 0.0330 - val_rx_mean_absolute_error: 0.2003 - val_disk_mean_absolute_error: 0.0133

# %%
disagg_model.evaluate(x=disagg_val_X, y=disagg_val_y, verbose=1)
# Out:
# 5000/5000 [==============================] - 0s 78us/step
# [0.05159711599946022,
#  0.0022215350004349604,
#  0.002510456895455718,
#  0.044980605125427245,
#  0.001884519204056896,
#  0.026709802669286728,
#  0.032997824811935424,
#  0.2003416814804077,
#  0.01328142861769711]

# %% [markdown]
# ## Test disaggregation model

# %%
disagg_val_X = validation_set["Power12"].as_matrix()[:, numpy.newaxis]
disagg_val_y = validation_set.drop("Power12", axis=1)

# %%
def make_disagg_prediction(power_X):
    
    cpu_pred = []
    tx_pred = []
    rx_pred = []
    disk_pred = []
    
    for i in range(power_X.shape[0] - 51):
        _inp = power_X[i:i+51][numpy.newaxis,:, numpy.newaxis]
    
        # Disaggregation part
        disagg_predictions = disagg_model.predict(_inp)
    
        cpu_pred.append(disagg_predictions[0].ravel())
        tx_pred.append(disagg_predictions[1].ravel())
        rx_pred.append(disagg_predictions[2].ravel())
        disk_pred.append(disagg_predictions[3].ravel())
        
    return (numpy.array(cpu_pred), numpy.array(tx_pred), numpy.array(rx_pred), numpy.array(disk_pred))

# %%
predictions = make_disagg_prediction(disagg_val_X.ravel())

# %%
cpu_pred = predictions[0].ravel()[:2000]
tx_pred = predictions[1].ravel()[:2000]
rx_pred = predictions[2].ravel()[:2000]
disk_pred = predictions[3].ravel()[:2000]

cpu_true = disagg_val_y["CPU_user"][25:-26].as_matrix()[:2000]
tx_true = disagg_val_y["net_TX"][25:-26].as_matrix()[:2000]
rx_true = disagg_val_y["net_RX"][25:-26].as_matrix()[:2000]
disk_true = disagg_val_y["disk_p2"][25:-26].as_matrix()[:2000]

# %%
print("CPU")
fig = plotter.figure(figsize=(25,5))
plotter.plot(cpu_true, linewidth=0.5, label="True")
plotter.plot(cpu_pred, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("TX")
fig = plotter.figure(figsize=(25,5))
plotter.plot(tx_true, linewidth=0.5, label="True")
plotter.plot(tx_pred, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("RX")
fig = plotter.figure(figsize=(25,5))
plotter.plot(rx_true, linewidth=0.5, label="True")
plotter.plot(rx_pred, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("Disk")
fig = plotter.figure(figsize=(25,5))
plotter.plot(disk_true, linewidth=0.5, label="True")
plotter.plot(disk_pred, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()
# Out:
# CPU
# TX
# RX
# Disk

# %% [markdown]
# ------

# %% [markdown]
# # System operation

# %% [markdown]
# Define the prediction system consisting of the trained aggregation and disaggregation models

# %%
def make_prediction(power_X):
    
    cpu_pred = []
    tx_pred = []
    rx_pred = []
    disk_pred = []
    
    for i in range(power_X.shape[0] - 51):
        _inp = power_X[i:i+51][numpy.newaxis,:, numpy.newaxis]
    
        # Disaggregation part
        disagg_predictions = disagg_model.predict(_inp)
    
        cpu_pred.append(disagg_predictions[0].ravel())
        tx_pred.append(disagg_predictions[1].ravel())
        rx_pred.append(disagg_predictions[2].ravel())
        disk_pred.append(disagg_predictions[3].ravel())
    
    data = numpy.vstack([numpy.array(cpu_pred).ravel(),
                         numpy.array(tx_pred).ravel(),
                         numpy.array(rx_pred).ravel(),
                         numpy.array(disk_pred).ravel()])
    
    data = data.T
    
    power_pred = []
    for j in range(data.shape[0] - 51):
        _inp = data[j:j+51][numpy.newaxis,:,:]

        # Aggregation model
        power_pred.append(agg_model.predict(_inp))
    
    return numpy.array(power_pred).ravel()

# %%
columns = testing_set.columns

testing_set = pandas.DataFrame(scaler.transform(testing_set.as_matrix()), columns=columns)
testing_set.describe()
# Out:
#            CPU_user        net_TX         net_RX       disk_p2       Power12
# count  28560.000000  28560.000000   28560.000000  28560.000000  28560.000000
# mean       0.367288      0.206087       0.271533      0.066884      0.435899
# std      777.141771    409.294962     924.276762    149.316592      0.208302
# min   -92865.993714 -48909.199017 -110447.863636 -17842.855814      0.000000
# 25%        0.011226      0.036855       0.056818      0.000000      0.220284
# 50%        0.435564      0.239558       0.056818      0.000000      0.459948
# 75%        0.489448      0.239558       0.484848      0.000000      0.551680
# max    92865.997306  48909.707617  110448.443182  17842.855814      1.057278

# %% [markdown]
# Test on normal behavior

# %%
test_norm_X = testing_set["Power12"].as_matrix().ravel()

# %% [markdown]
# Make power prediction after disaggregation

# %%
power_prediction = make_prediction(test_norm_X)

# %% [markdown]
# Test plots and differences in prediction of normal data

# %%
power_input = test_norm_X[76:-26]
net_rx = testing_set["net_TX"].clip(lower=0, upper=1).as_matrix().ravel()[76:-26]
cpu = testing_set["CPU_user"].clip(lower=0, upper=1).as_matrix().ravel()[76:-26]
print(power_input.shape)
print(net_rx.shape)
print("Normal Behavior")
fig = plotter.figure(figsize=(25,5))
plotter.plot(power_input, linewidth=0.5, label="True")
plotter.plot(power_prediction, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("Finer look at first 1000 predictions")
fig = plotter.figure(figsize=(25,5))
plotter.plot(power_input, linewidth=0.5, label="True")
plotter.plot(power_prediction, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("difference")
diff = numpy.abs(power_input - power_prediction)
thres, outliers = run_thresholding(diff)
fig = plotter.figure(figsize=(25,5))
plotter.plot(diff, linewidth=0.5, label="Difference")
plotter.plot(thres, linewidth=0.5, label="Threshold")
plotter.plot(outliers, 'r.', linewidth=0.5, label="Outliers")
#plotter.plot(power_prediction[-1000:], linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("difference")
diff = pandas.Series(numpy.abs(power_input - power_prediction)).rolling(5).median().fillna(0)
print(diff.shape)
thres, outliers = run_thresholding(diff.as_matrix().ravel())
fig = plotter.figure(figsize=(25,5))
plotter.plot(diff.as_matrix(), linewidth=0.5, label="Difference")
plotter.plot(thres, linewidth=0.5, label="Threshold")
plotter.plot(outliers, 'r.', linewidth=0.5, label="Outliers")
plotter.ylim(0,1)
plotter.legend()
plotter.show()

print("look at RX")
fig = plotter.figure(figsize=(25,5))
plotter.plot(net_rx, linewidth=0.5, label="True")
#plotter.plot(power_prediction, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()

print("look at CPU")
fig = plotter.figure(figsize=(25,5))
plotter.plot(cpu, linewidth=0.5, label="True")
#plotter.plot(power_prediction, linewidth=0.5, label="Prediction")
plotter.legend()
plotter.show()
# Out:
# (28458,)
# (28458,)
# Normal Behavior
# Finer look at first 1000 predictions
# difference
# difference
# (28458,)
# look at RX
# look at CPU
