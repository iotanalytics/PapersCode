# %%
import pandas
import numpy
import matplotlib.pyplot as plotter
from pathlib import Path
import seaborn
from scipy.signal import *
from scipy.stats import probplot

# %%
data = Path("../data/summer_proc_data/")
files = list(data.iterdir())
print(files)
# Out:
# [PosixPath('../data/summer_proc_data/summer_proc_disk.csv'), PosixPath('../data/summer_proc_data/summer_proc_voltage.csv'), PosixPath('../data/summer_proc_data/summer_proc_power.csv'), PosixPath('../data/summer_proc_data/summer_proc_tx.csv'), PosixPath('../data/summer_proc_data/summer_proc_cpu.csv'), PosixPath('../data/summer_proc_data/summer_proc_rx.csv')]

# %%
disk = pandas.read_csv(str(data/"summer_proc_disk.csv")).drop("Unnamed: 0", axis=1)
print(disk.columns)
cpu = pandas.read_csv(str(data/"summer_proc_cpu.csv")).drop("Unnamed: 0", axis=1)
print(cpu.columns)
power = pandas.read_csv(str(data/"summer_proc_power.csv")).drop("Unnamed: 0", axis=1)
# context = pandas.read_csv(str(data/"summer_simple_context.csv")).drop("Unnamed: 0", axis=1)
tx = pandas.read_csv(str(data/"summer_proc_tx.csv")).drop("Unnamed: 0", axis=1)
rx = pandas.read_csv(str(data/"summer_proc_rx.csv")).drop("Unnamed: 0", axis=1)
# Out:
# Index(['Time', 'disk_p2'], dtype='object')
# Index(['Time', 'CPU_user'], dtype='object')

# %% [markdown]
# ----

# %% [markdown]
# # Visualize and get info on data

# %%
time = power["Time"]
power = power.drop("Time", axis=1)
#power = medfilt(power.as_matrix().ravel(), 21)
power = pandas.DataFrame(power.as_matrix().ravel(), columns=["power"])
power.head()
# Out:
#          power
# 0  1450.609756
# 1  1450.609756
# 2  1331.707317
# 3  1427.642276
# 4  1384.756098

# %%
power.plot(kind="density")
plotter.show()
power.plot(kind="box")
plotter.show()
power.plot()
plotter.show()

# %%
cpu
# Out:
#                             Time     CPU_user
# 0      2018-07-10 18:30:05+00:00    10.000000
# 1      2018-07-10 18:30:05+00:00    10.000000
# 2      2018-07-10 18:30:10+00:00     8.000000
# 3      2018-07-10 18:30:15+00:00    12.000000
# 4      2018-07-10 18:30:20+00:00     9.500000
# 5      2018-07-10 18:30:25+00:00     7.000000
# 6      2018-07-10 18:30:30+00:00    13.166667
# 7      2018-07-10 18:30:35+00:00    12.333333
# 8      2018-07-10 18:30:40+00:00     8.000000
# 9      2018-07-10 18:30:45+00:00    13.333333
# 10     2018-07-10 18:30:50+00:00    15.666667
# 11     2018-07-10 18:30:55+00:00    13.000000
# 12     2018-07-10 18:31:00+00:00    15.333333
# 13     2018-07-10 18:31:05+00:00    15.166667
# 14     2018-07-10 18:31:10+00:00    11.000000
# 15     2018-07-10 18:31:15+00:00    11.833333
# 16     2018-07-10 18:31:20+00:00    30.166667
# 17     2018-07-10 18:31:25+00:00   349.000000
# 18     2018-07-10 18:31:30+00:00   432.000000
# 19     2018-07-10 18:31:35+00:00   574.833333
# 20     2018-07-10 18:31:40+00:00   555.666667
# 21     2018-07-10 18:31:45+00:00   542.000000
# 22     2018-07-10 18:31:50+00:00   541.500000
# 23     2018-07-10 18:31:55+00:00   431.500000
# 24     2018-07-10 18:32:00+00:00   433.500000
# 25     2018-07-10 18:32:05+00:00   586.500000
# 26     2018-07-10 18:32:10+00:00   541.500000
# 27     2018-07-10 18:32:15+00:00   539.500000
# 28     2018-07-10 18:32:20+00:00   542.500000
# 29     2018-07-10 18:32:25+00:00   433.000000
# ...                          ...          ...
# 34530  2018-07-12 18:27:30+00:00   416.500000
# 34531  2018-07-12 18:27:35+00:00   572.666667
# 34532  2018-07-12 18:27:40+00:00   932.333333
# 34533  2018-07-12 18:27:45+00:00  1050.666667
# 34534  2018-07-12 18:27:50+00:00  1049.333333
# 34535  2018-07-12 18:27:55+00:00   831.000000
# 34536  2018-07-12 18:28:00+00:00  1047.666667
# 34537  2018-07-12 18:28:05+00:00  1046.833333
# 34538  2018-07-12 18:28:10+00:00   745.000000
# 34539  2018-07-12 18:28:15+00:00   558.500000
# 34540  2018-07-12 18:28:20+00:00   541.500000
# 34541  2018-07-12 18:28:25+00:00   438.000000
# 34542  2018-07-12 18:28:30+00:00   544.500000
# 34543  2018-07-12 18:28:35+00:00   544.000000
# 34544  2018-07-12 18:28:40+00:00   493.000000
# 34545  2018-07-12 18:28:45+00:00  1025.000000
# 34546  2018-07-12 18:28:50+00:00  1069.000000
# 34547  2018-07-12 18:28:55+00:00   862.000000
# 34548  2018-07-12 18:29:00+00:00  1074.333333
# 34549  2018-07-12 18:29:05+00:00  1072.166667
# 34550  2018-07-12 18:29:10+00:00  1077.166667
# 34551  2018-07-12 18:29:15+00:00  1073.333333
# 34552  2018-07-12 18:29:20+00:00   858.500000
# 34553  2018-07-12 18:29:25+00:00   916.166667
# 34554  2018-07-12 18:29:30+00:00   570.333333
# 34555  2018-07-12 18:29:35+00:00   436.500000
# 34556  2018-07-12 18:29:40+00:00   682.833333
# 34557  2018-07-12 18:29:45+00:00  1024.666667
# 34558  2018-07-12 18:29:50+00:00   839.500000
# 34559  2018-07-12 18:29:55+00:00  1054.833333
#
# [34560 rows x 2 columns]

# %%
cpu.plot(kind="density")
plotter.show()
cpu.plot(kind="box")
plotter.show()
cpu.plot()
plotter.show()

# %%
#disk = disk.drop(disk.columns[2], axis=1)
disk.describe()
# Out:
#             disk_p2
# count  34560.000000
# mean     229.147859
# std      486.386083
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max     3900.000000

# %%
disk.plot(kind="density")
plotter.show()
disk.plot(kind="box")
plotter.show()

# %%
tx.describe()
# Out:
#              net_TX
# count  34560.000000
# mean      76.361343
# std       58.354279
# min       12.000000
# 25%       15.000000
# 50%       78.000000
# 75%       97.500000
# max      251.000000

# %%
tx.plot(kind="density")
plotter.show()
tx.plot(kind="box")
plotter.show()

# %%
rx.describe()
# Out:
#              net_RX
# count  34560.000000
# mean       9.475424
# std        1.213157
# min        8.000000
# 25%        8.000000
# 50%       10.000000
# 75%       10.000000
# max       52.666667

# %%
rx.plot(kind="density")
plotter.show()
rx.plot(kind="box")
plotter.show()

# %%
all_data = pandas.concat([cpu, tx, rx, disk, power], axis=1, join="inner").drop("Time", axis=1).fillna(0)
all_data.describe()
# Out:
#            CPU_user        net_TX        net_RX       disk_p2         power
# count  34560.000000  34560.000000  34560.000000  34560.000000  34560.000000
# mean     396.757533     76.361343      9.475424    229.147859   1604.634287
# std      337.801514     58.354279      1.213157    486.386083    202.190383
# min        5.000000     12.000000      8.000000      0.000000   1276.829268
# 25%       13.000000     15.000000      8.000000      0.000000   1407.926829
# 50%      436.000000     78.000000     10.000000      0.000000   1619.715447
# 75%      544.166667     97.500000     10.000000      0.000000   1716.463415
# max     1202.166667    251.000000     52.666667   3900.000000   2455.487805

# %%
all_data
# Out:
#           CPU_user  net_TX  net_RX      disk_p2        power
# 0        10.000000    78.0     8.0     0.000000  1450.609756
# 1        10.000000    78.0     8.0     0.000000  1450.609756
# 2         8.000000   111.0     8.0     0.000000  1331.707317
# 3        12.000000    97.5    10.0     0.000000  1427.642276
# 4         9.500000    97.5    10.0     0.000000  1384.756098
# 5         7.000000    78.0     8.5     0.000000  1313.414634
# 6        13.166667    97.5    10.5     0.000000  1357.723577
# 7        12.333333   114.5    10.5     0.000000  1400.000000
# 8         8.000000    95.0     8.5     0.000000  1316.463415
# 9        13.333333    97.5    10.0     0.000000  1395.934959
# 10       15.666667    97.5    10.0     0.000000  1386.585366
# 11       13.000000    78.0     8.5     0.000000  1368.292683
# 12       15.333333    97.5    10.5     0.000000  1306.097561
# 13       15.166667   131.0    10.5     0.000000  1372.560976
# 14       11.000000    78.5     8.5     0.000000  1349.390244
# 15       11.833333    97.5    10.0     0.000000  1388.211382
# 16       30.166667    97.5    10.0     0.000000  1503.048780
# 17      349.000000    78.0     8.5     0.000000  1625.609756
# 18      432.000000    78.0     8.5     0.000000  1680.487805
# 19      574.833333   130.5    10.0     0.000000  1672.357724
# 20      555.666667    97.5    10.0     0.000000  1735.365854
# 21      542.000000    97.5    10.0     0.000000  1612.195122
# 22      541.500000    97.5    10.0     0.000000  1629.268293
# 23      431.500000    78.0     8.5     0.000000  1696.341463
# 24      433.500000    78.0     8.5     0.000000  1665.853659
# 25      586.500000   131.5    11.0     0.000000  1687.804878
# 26      541.500000    97.5    10.0     0.000000  1581.707317
# 27      539.500000    97.5    10.0     0.000000  1685.772358
# 28      542.500000    97.5    10.0     0.000000  1681.097561
# 29      433.000000    78.0     8.5     0.000000  1634.756098
# ...            ...     ...     ...          ...          ...
# 34530   416.500000    12.0     8.0  1030.000000  1713.414634
# 34531   572.666667    15.0    10.0  1348.333333  1765.040650
# 34532   932.333333    15.0    10.0  1226.666667  1950.000000
# 34533  1050.666667    15.0    10.0  1420.000000  2004.878049
# 34534  1049.333333    15.0    10.0  1245.000000  1924.390244
# 34535   831.000000    12.0     8.0  1155.000000  1872.560976
# 34536  1047.666667    15.0    10.0  1266.666667  2029.674797
# 34537  1046.833333    15.0    10.0  1413.333333  1990.853659
# 34538   745.000000    12.0     8.0   800.000000  1830.487805
# 34539   558.500000    15.0    10.0    36.666667  1640.243902
# 34540   541.500000    15.0    10.0     3.333333  1641.463415
# 34541   438.000000    12.0     8.0     0.000000  1682.317073
# 34542   544.500000    15.0    10.0     0.000000  1728.455285
# 34543   544.000000    15.0    10.0     0.000000  1660.975610
# 34544   493.000000    12.0     8.0     0.000000  1793.902439
# 34545  1025.000000    15.0    10.0     0.000000  1973.170732
# 34546  1069.000000    15.0    10.0     0.000000  1925.000000
# 34547   862.000000    12.0     8.0     0.000000  1910.365854
# 34548  1074.333333    15.0    10.0     0.000000  1873.983740
# 34549  1072.166667    15.0    10.0     0.000000  1887.195122
# 34550  1077.166667    15.0    10.0     0.000000  1935.365854
# 34551  1073.333333    15.0    10.0     0.000000  1900.000000
# 34552   858.500000    12.0     8.0     0.000000  1881.097561
# 34553   916.166667    15.0    10.0     0.000000  1784.552846
# 34554   570.333333    15.0    10.0     0.000000  1681.097561
# 34555   436.500000    12.0     8.0     0.000000  1643.902439
# 34556   682.833333    15.0    10.0   323.333333  1806.097561
# 34557  1024.666667    15.0    10.0  1206.666667  2019.512195
# 34558   839.500000    12.0     8.0   980.000000  1929.878049
# 34559  1054.833333    15.0    10.0  1180.000000  1936.178862
#
# [34560 rows x 5 columns]

# %%
all_data.plot()
plotter.show()

# %%
plotter.figure(figsize=(15,15))
seaborn.heatmap(all_data.corr(), annot=True)
plotter.show()

# %% [markdown]
# ## Define data loader

# %%
class DataLoader:
    """
        Defines data loader for seq2point model.
    """
    
    def __init__(self, X, y, window=5):
        self.X = X
        self.y = y
        self.window = window
        
    def __len__(self):
        return (self.X.shape[0]-(self.window + 1))
    
    def __getitem__(self, i):
        """
            Returns single batch of data in flat seq2point compatible format.
        """
        X = self.X[i: i+self.window, :]
        # y = self.y[i+int(self.window/2)]
        y = self.y[i]
        
        return (X, y)


class BatchLoader:
    """
        Creates batches from data provided by dataloader.
    """
    
    def __init__(self, dataloader, batch_size=32):
        self.dloader = dataloader
        self.batch_size = batch_size
        self.samples = list(range(len(self.dloader)))
        
    def __len__(self):
        return int(len(self.dloader)/self.batch_size) - 1
        
    def __getitem__(self, i):
        i = i*self.batch_size
        _samples = self.samples[i: i+self.batch_size]
        
        X=[]
        y=[]
        
        for j in range(len(_samples)):
            _X, _y = self.dloader[_samples[j]]
            X.append(_X.ravel())
            y.append(_y)
        
        return numpy.array(X), numpy.array(y)

# %%
class ConvBatchLoader:
    """
        Creates conv batches from data provided by dataloader.
    """
    
    def __init__(self, dataloader, batch_size=32):
        self.dloader = dataloader
        self.batch_size = batch_size
        self.samples = list(range(len(self.dloader)))
        
    def __len__(self):
        return int(len(self.dloader)/self.batch_size) - 1
        
    def __getitem__(self, i):
        i = i*self.batch_size
        _samples = self.samples[i: i+self.batch_size]
        
        X=[]
        y=[]
        
        for j in range(len(_samples)):
            _X, _y = self.dloader[_samples[j]]
            X.append(_X)
            y.append(_y)
        
        return numpy.array(X), numpy.array(y)

# %%
def run_thresholding(data):
        arr = pandas.Series(data)
        mean = 0
        count = 0
        outliers = numpy.zeros_like(arr)
        thres = numpy.zeros_like(arr)
        means = numpy.zeros_like(arr)
        cmeans = arr.expanding().mean()
        std = 0

        # Compute running stats

        m2 = 0
        for i in range(len(arr)):

            if i > 100 and arr[i] > (mean + 4 * std):
                outliers[i] = data[i]
                means[i] = mean
                thres[i] = mean + (4 * std)
                continue

            count = count + 1
            delta = arr[i] - mean

            mean = mean + (delta/count)
            means[i] = mean

            new_delta = arr[i] - mean
            m2 = m2 + delta * new_delta

            std = numpy.sqrt(m2 / count)

            thres[i] = mean + (4 * std)
            
        return thres, outliers

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
columns = all_data.columns

all_data = pandas.DataFrame(scaler.fit_transform(all_data.as_matrix()), columns=columns)

y = all_data["power"]
X = all_data.drop("power", axis=1)

print(X.head())
print(y.head())
# Out:
#    CPU_user    net_TX    net_RX  disk_p2
# 0  0.004177  0.276151  0.000000      0.0
# 1  0.004177  0.276151  0.000000      0.0
# 2  0.002506  0.414226  0.000000      0.0
# 3  0.005847  0.357741  0.044776      0.0
# 4  0.003759  0.357741  0.044776      0.0
# 0    0.147439
# 1    0.147439
# 2    0.046560
# 3    0.127953
# 4    0.091568
# Name: power, dtype: float64

# %%
all_data.shape
# Out:
# (34560, 5)

# %%
def data_gen(loader):
    while 1:
        for i in range(len(loader)):
            yield loader[i]

# %% [markdown]
# ### Deep

# %%
from keras.layers import Conv1D, Input, Dense, Flatten, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error
# Out:
# /home/adityas/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
y = all_data["power"]
X = all_data.drop("power", axis=1)

# %%
bloader = ConvBatchLoader(dataloader=DataLoader(X=X[:25000].as_matrix(), y=y[:25000].as_matrix(), window=101), batch_size=64)
vloader = ConvBatchLoader(dataloader=DataLoader(X=X[25000:30000].as_matrix(), y=y[25000:30000].as_matrix(), window=101), batch_size=5000)

# %%
tloader = data_gen(bloader)

# %%
_input = Input(shape=(101, 4))
conv = Conv1D(kernel_size=10, filters=20, activation="relu")(_input)
conv = Conv1D(kernel_size=10, filters=10, activation="relu")(conv)
conv = MaxPooling1D(pool_size=2)(conv)
conv = Conv1D(kernel_size=5, filters=10, activation="relu")(conv)
conv = MaxPooling1D(pool_size=2)(conv)
conv = Conv1D(kernel_size=5, filters=10, activation="sigmoid")(conv)
flat = Flatten()(conv)
out = Dense(1, activation="sigmoid")(flat)

# %%
model = Model(inputs=_input, outputs=out)
model.compile(loss="mean_squared_error", optimizer="adam", metrics=["mean_absolute_error"])
estopper = EarlyStopping(monitor="val_loss", patience=10)
model.fit_generator(callbacks=[estopper], generator=tloader, validation_data=vloader[0], shuffle=True, steps_per_epoch=500, epochs=100)
# Out:
# Epoch 1/100
# 500/500 [==============================] - 13s 25ms/step - loss: 0.0192 - mean_absolute_error: 0.1075 - val_loss: 0.0072 - val_mean_absolute_error: 0.0654
# Epoch 2/100
# 500/500 [==============================] - 12s 24ms/step - loss: 0.0062 - mean_absolute_error: 0.0603 - val_loss: 0.0051 - val_mean_absolute_error: 0.0546
# Epoch 3/100
# 500/500 [==============================] - 14s 27ms/step - loss: 0.0050 - mean_absolute_error: 0.0537 - val_loss: 0.0044 - val_mean_absolute_error: 0.0513
# Epoch 4/100
# 500/500 [==============================] - 14s 28ms/step - loss: 0.0043 - mean_absolute_error: 0.0497 - val_loss: 0.0041 - val_mean_absolute_error: 0.0485
# Epoch 5/100
# 500/500 [==============================] - 14s 28ms/step - loss: 0.0039 - mean_absolute_error: 0.0473 - val_loss: 0.0037 - val_mean_absolute_error: 0.0467
# Epoch 6/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0036 - mean_absolute_error: 0.0455 - val_loss: 0.0032 - val_mean_absolute_error: 0.0430
# Epoch 7/100
# 500/500 [==============================] - 14s 29ms/step - loss: 0.0035 - mean_absolute_error: 0.0447 - val_loss: 0.0033 - val_mean_absolute_error: 0.0447
# Epoch 8/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0034 - mean_absolute_error: 0.0443 - val_loss: 0.0033 - val_mean_absolute_error: 0.0446
# Epoch 9/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0032 - mean_absolute_error: 0.0429 - val_loss: 0.0030 - val_mean_absolute_error: 0.0411
# Epoch 10/100
# 500/500 [==============================] - 15s 29ms/step - loss: 0.0031 - mean_absolute_error: 0.0427 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 11/100
# 500/500 [==============================] - 16s 31ms/step - loss: 0.0032 - mean_absolute_error: 0.0427 - val_loss: 0.0030 - val_mean_absolute_error: 0.0411
# Epoch 12/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0030 - mean_absolute_error: 0.0419 - val_loss: 0.0030 - val_mean_absolute_error: 0.0407
# Epoch 13/100
# 500/500 [==============================] - 16s 32ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 0.0029 - val_mean_absolute_error: 0.0399
# Epoch 14/100
# 500/500 [==============================] - 16s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0417 - val_loss: 0.0034 - val_mean_absolute_error: 0.0453
# Epoch 15/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0415 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 16/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0029 - mean_absolute_error: 0.0409 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 17/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0029 - mean_absolute_error: 0.0410 - val_loss: 0.0028 - val_mean_absolute_error: 0.0394
# Epoch 18/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0412 - val_loss: 0.0027 - val_mean_absolute_error: 0.0398
# Epoch 19/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0406 - val_loss: 0.0033 - val_mean_absolute_error: 0.0454
# Epoch 20/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0028 - mean_absolute_error: 0.0406 - val_loss: 0.0028 - val_mean_absolute_error: 0.0404
# Epoch 21/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 22/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 23/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0404 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 24/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0403 - val_loss: 0.0028 - val_mean_absolute_error: 0.0396
# Epoch 25/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0404 - val_loss: 0.0030 - val_mean_absolute_error: 0.0409
# Epoch 26/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0401 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 27/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0027 - mean_absolute_error: 0.0399 - val_loss: 0.0027 - val_mean_absolute_error: 0.0397
# Epoch 28/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0030 - val_mean_absolute_error: 0.0426
# Epoch 29/100
# 500/500 [==============================] - 16s 31ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 0.0034 - val_mean_absolute_error: 0.0464
# Epoch 30/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0399 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 31/100
# 500/500 [==============================] - 15s 31ms/step - loss: 0.0027 - mean_absolute_error: 0.0398 - val_loss: 0.0029 - val_mean_absolute_error: 0.0411
# Epoch 32/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 33/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0396 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 34/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0395 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 35/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0397 - val_loss: 0.0029 - val_mean_absolute_error: 0.0400
# Epoch 36/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 0.0031 - val_mean_absolute_error: 0.0411
# Epoch 37/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0394 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 38/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 0.0028 - val_mean_absolute_error: 0.0398
# Epoch 39/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 40/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0030 - val_mean_absolute_error: 0.0410
# Epoch 41/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 42/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0395 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 43/100
# 500/500 [==============================] - 15s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0391 - val_loss: 0.0036 - val_mean_absolute_error: 0.0464
# Epoch 44/100
# 500/500 [==============================] - 15s 30ms/step - loss: 0.0026 - mean_absolute_error: 0.0393 - val_loss: 0.0027 - val_mean_absolute_error: 0.0398

# %%
bloader = ConvBatchLoader(dataloader=DataLoader(X=X[30000:].as_matrix(), y=y[30000:].as_matrix(), window=201), batch_size=4000)

# %%
X, y = bloader[0]
print(X.shape)
print(y.shape)

pred = model.predict(X).ravel()
# Out:
# (4000, 201, 4)
# (4000,)

# %%
print(pred.shape)
print(mean_absolute_error(y_true=y, y_pred=model.predict(X)))
fig = plotter.figure(figsize=(25,5))
plotter.plot(y[:1000], linewidth=0.5, label="True")
plotter.plot(pred[:1000], linewidth=0.5, label="Prediction")
plotter.ylim(0,1)
plotter.legend()
plotter.show()

diff = y - pred

pandas.Series(diff).plot(kind="density")
plotter.show()

bound, out = run_thresholding(diff)
fig = plotter.figure(figsize=(25,5))
plotter.plot(bound, linewidth=0.5, label="bound")
plotter.plot(diff, linewidth=0.5, label="diff")
plotter.plot(out, 'r.', linewidth=0.5, label="outliers")
#plotter.plot(mean - (3*std), linewidth=0.5, label="Lower bound")
plotter.legend()
plotter.show()
# Out:
# (4000,)
# 0.040492217534634604

# %% [markdown]
# ## Make test set

# %%
data = Path("../data/summer_proc_test/")
files = list(data.iterdir())
print(files)
# Out:
# [PosixPath('../data/summer_proc_test/summer_proc_test_cpu.csv'), PosixPath('../data/summer_proc_test/summer_proc_test_tx.csv'), PosixPath('../data/summer_proc_test/summer_proc_test_rx.csv'), PosixPath('../data/summer_proc_test/summer_proc_test_voltage.csv'), PosixPath('../data/summer_proc_test/summer_proc_test_power.csv'), PosixPath('../data/summer_proc_test/summer_proc_test_disk.csv')]

# %%
disk = pandas.read_csv(str(data/"summer_proc_test_disk.csv")).drop("Unnamed: 0", axis=1)
cpu = pandas.read_csv(str(data/"summer_proc_test_cpu.csv")).drop("Unnamed: 0", axis=1)
power = pandas.read_csv(str(data/"summer_proc_test_power.csv")).drop("Unnamed: 0", axis=1).fillna(0)
tx = pandas.read_csv(str(data/"summer_proc_test_tx.csv")).drop("Unnamed: 0", axis=1)
rx = pandas.read_csv(str(data/"summer_proc_test_rx.csv")).drop("Unnamed: 0", axis=1)

# %%
power = power.drop("Time", axis=1)
power = pandas.DataFrame(power.as_matrix().ravel(), columns=["power"])
power.head()
# Out:
#          power
# 0  1381.097561
# 1  1381.097561
# 2  1591.056911
# 3  1598.170732
# 4  1591.463415

# %%
test_data = pandas.concat([cpu, tx, rx, disk, power], axis=1, join="inner").drop("Time", axis=1).fillna(0)
test_data.describe()
# Out:
#           CPU_user       net_TX       net_RX      disk_p2        power
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean    503.303935   264.406250   211.630556   222.303241  1804.014651
# std     399.552048   599.688124   606.191497   484.812885   332.300303
# min       6.000000    12.000000     8.000000     0.000000  1286.585366
# 25%      13.666667    15.000000     8.000000     0.000000  1504.878049
# 50%     524.750000    20.000000    10.000000     0.000000  1784.756098
# 75%     879.875000   144.000000    10.500000     3.333333  2008.180894
# max    1126.500000  2676.500000  2672.500000  3405.000000  2684.146341

# %%
columns = test_data.columns

test_data = pandas.DataFrame(scaler.transform(test_data.as_matrix()), columns=columns)

y = test_data["power"]
X = test_data.drop("power", axis=1)

# %%
test_data.plot(kind="density")
plotter.show()

# %%
bloader = ConvBatchLoader(dataloader=DataLoader(X=X.as_matrix(), y=y.as_matrix(), window=201), batch_size=4000)

# %%
X, y = bloader[0]
print(X.shape)
print(y.shape)

pred = model.predict(X).ravel()
# Out:
# (1238, 201, 4)
# (1238,)

# %%
print(pred.shape)
print(mean_absolute_error(y_true=y, y_pred=model.predict(X)))

fig = plotter.figure(figsize=(25,5))
plotter.plot(test_data["net_RX"].as_matrix()[100:-100], linewidth=0.5, label="True")
plotter.legend()
plotter.show()

fig = plotter.figure(figsize=(25,5))
plotter.plot(y, linewidth=0.5, label="True")
plotter.plot(pred, linewidth=0.5, label="Prediction")
plotter.ylim(0,1)
plotter.legend()
plotter.show()

diff = y - pred

pandas.Series(diff).plot(kind="density")
plotter.show()

bound, out = run_thresholding(diff)
fig = plotter.figure(figsize=(25,5))
plotter.plot(bound, linewidth=0.5, label="bound")
plotter.plot(diff, linewidth=0.5, label="diff")
plotter.plot(out, 'r.', linewidth=0.5, label="outliers")
#plotter.plot(mean - (3*std), linewidth=0.5, label="Lower bound")
plotter.legend()
plotter.show()
# Out:
# (1238,)
# 0.20192440879416737
