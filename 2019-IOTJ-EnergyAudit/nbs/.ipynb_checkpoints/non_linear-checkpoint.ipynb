# %%
import sys
sys.path.append("/home/adityas/UGA/SensorWeb/scripts/Summer2018/code")

from pathlib import Path
import pandas
import matplotlib.pyplot as plotter
import numpy
from scipy.signal import *

# %% [markdown]
# Import data loaders and all

# %%
from model.data_loader import DataLoader

# %%
files = list(Path("../data/hs_nonlinear/").iterdir())
files = sorted(files, key=lambda x: int(str(x).split("/")[-1].split(".")[0].split("_")[-1]))
files[:10]
# Out:
# [PosixPath('../data/hs_nonlinear/run_0.csv'),
#  PosixPath('../data/hs_nonlinear/run_1.csv'),
#  PosixPath('../data/hs_nonlinear/run_2.csv'),
#  PosixPath('../data/hs_nonlinear/run_3.csv'),
#  PosixPath('../data/hs_nonlinear/run_4.csv'),
#  PosixPath('../data/hs_nonlinear/run_5.csv'),
#  PosixPath('../data/hs_nonlinear/run_6.csv'),
#  PosixPath('../data/hs_nonlinear/run_7.csv'),
#  PosixPath('../data/hs_nonlinear/run_8.csv'),
#  PosixPath('../data/hs_nonlinear/run_9.csv')]

# %% [markdown]
# Initialize data loader

# %% [markdown]
# ## Data stats

# %%
dataloader = DataLoader(files)

# %% [markdown]
# Print some statistics to look at distributions

# %%
test_data = dataloader[0]
print(test_data.head(5))
test_data.plot(kind="density")
plotter.legend()
plotter.show()
# Out:
#         cpu      disk   network    energy
# 0  0.349068  0.031405  0.057403  0.102001
# 1  0.854683  0.000000  0.000000  0.232537
# 2  0.977380  0.000000  0.000000  0.264485
# 3  1.000000  0.000000  0.000000  0.270374
# 4  0.786332  0.000000  0.018504  0.214829

# %% [markdown]
# Have a peek at the target function

# %%
# !head ../scripts/hs_nonlinear.log -n 15
# Out:
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# INFO:HighSensitivityNonLinearEM:Energy meter init with factors cpu:0.26037420478250894^1 +disk:0.2615279699043457^2 +net:0.2594535577782813^2
# INFO:Device:Device initialised
# DEBUG:Device:Device in state compute
# DEBUG:Device:Device in state net_send
# DEBUG:Device:Device in state read
# DEBUG:Device:Device in state compute

# %% [markdown]
# Take a look at the waveforms

# %%
test_data[:200].plot()
plotter.legend()
plotter.show()

# %%
corr = test_data.corr()
plotter.imshow(corr, cmap="gray")
plotter.xticks(numpy.arange(len(corr.columns)))
plotter.yticks(numpy.arange(len(corr.index)))
plotter.xlabel(list(corr.columns))
plotter.ylabel(list(reversed(list(corr.index))))
plotter.show()

# %% [markdown]
# Clean up

# %%
del test_data

# %% [markdown]
# ## Learn function

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.neural_network import MLPRegressor

# %%
regressor = MLPRegressor(hidden_layer_sizes=(5,), early_stopping=False, activation='logistic')

# %%
for i in range(3):
    for batch in range(len(dataloader)):
        data = dataloader[i]
        y = data["energy"]
        X = data.drop("energy", axis=1)
        
        regressor.partial_fit(X, y)
        
        print(f"For epoch {i} batch {batch} score is {mean_absolute_error(y_pred=regressor.predict(X), y_true=y)}")

print(f"Regression coefficients are {regressor.coefs_}")
print(f"Bias {regressor.intercepts_}")
# Out:
# For epoch 0 batch 0 score is 0.10335694200036172
# For epoch 0 batch 1 score is 0.08558945730021557
# For epoch 0 batch 2 score is 0.06593964412778518
# For epoch 0 batch 3 score is 0.04682600515013932
# For epoch 0 batch 4 score is 0.03380955934966109
# For epoch 0 batch 5 score is 0.028543335220598032
# For epoch 0 batch 6 score is 0.027256112557697002
# For epoch 0 batch 7 score is 0.026873030187352615
# For epoch 0 batch 8 score is 0.026706722972935873
# For epoch 0 batch 9 score is 0.02648909659760966
# For epoch 0 batch 10 score is 0.02630525593127208
# For epoch 0 batch 11 score is 0.026155071511003058
# For epoch 0 batch 12 score is 0.026259927886341714
# For epoch 0 batch 13 score is 0.025811050488845636
# For epoch 0 batch 14 score is 0.02562984028807942
# For epoch 0 batch 15 score is 0.02575417076468027
# For epoch 0 batch 16 score is 0.025523641278281033
# For epoch 0 batch 17 score is 0.02527607383329347
# For epoch 0 batch 18 score is 0.024943093173356207
# For epoch 0 batch 19 score is 0.02486965250546114
# For epoch 0 batch 20 score is 0.024726236860320744
# For epoch 0 batch 21 score is 0.024573736764124117
# For epoch 0 batch 22 score is 0.024872796092497224
# For epoch 0 batch 23 score is 0.02442862913803611
# For epoch 0 batch 24 score is 0.02422979356736505
# For epoch 0 batch 25 score is 0.024056756854077238
# For epoch 0 batch 26 score is 0.023848323190913227
# For epoch 0 batch 27 score is 0.023662756125748474
# For epoch 0 batch 28 score is 0.023229266205037572
# For epoch 0 batch 29 score is 0.0231127092209618
# For epoch 0 batch 30 score is 0.02290465297225126
# For epoch 0 batch 31 score is 0.022668461600677335
# For epoch 0 batch 32 score is 0.02241371832005343
# For epoch 0 batch 33 score is 0.02246548864695307
# For epoch 0 batch 34 score is 0.022009785379404546
# For epoch 0 batch 35 score is 0.02168391936952281
# For epoch 0 batch 36 score is 0.021620514120198817
# For epoch 0 batch 37 score is 0.02127000207082475
# For epoch 0 batch 38 score is 0.021035868719298682
# For epoch 0 batch 39 score is 0.02106309179916713
# For epoch 0 batch 40 score is 0.020832138275301792
# For epoch 0 batch 41 score is 0.02062075445496197
# For epoch 0 batch 42 score is 0.020320784978281395
# For epoch 0 batch 43 score is 0.01980635769180904
# For epoch 0 batch 44 score is 0.020016063184015602
# For epoch 0 batch 45 score is 0.019918345058961208
# For epoch 0 batch 46 score is 0.019918603641910018
# For epoch 0 batch 47 score is 0.019134841150674937
# For epoch 0 batch 48 score is 0.018743623442484775
# For epoch 0 batch 49 score is 0.01880452073780745
# For epoch 0 batch 50 score is 0.018437938062714727
# For epoch 0 batch 51 score is 0.018392404775524843
# For epoch 0 batch 52 score is 0.017978854785707075
# For epoch 0 batch 53 score is 0.01789092950144298
# For epoch 0 batch 54 score is 0.01813681214153521
# For epoch 0 batch 55 score is 0.017558176887755853
# For epoch 0 batch 56 score is 0.018003502513993522
# For epoch 0 batch 57 score is 0.017257131730554466
# For epoch 0 batch 58 score is 0.01754235578021952
# For epoch 0 batch 59 score is 0.017116818950845835
# For epoch 0 batch 60 score is 0.017894276962947986
# For epoch 0 batch 61 score is 0.01683081554262205
# For epoch 0 batch 62 score is 0.017197455038924895
# For epoch 0 batch 63 score is 0.01706144259174693
# For epoch 0 batch 64 score is 0.01728685140250313
# For epoch 0 batch 65 score is 0.016703578816014125
# For epoch 0 batch 66 score is 0.01674181063200255
# For epoch 0 batch 67 score is 0.016987059918646304
# For epoch 0 batch 68 score is 0.016150772620818342
# For epoch 0 batch 69 score is 0.01618562621615137
# For epoch 0 batch 70 score is 0.016859731409225323
# For epoch 0 batch 71 score is 0.0165445797357991
# For epoch 0 batch 72 score is 0.01663305347611091
# For epoch 0 batch 73 score is 0.016448270370032436
# For epoch 0 batch 74 score is 0.01602082425768615
# For epoch 0 batch 75 score is 0.016159164559728937
# For epoch 0 batch 76 score is 0.015915903644573345
# For epoch 0 batch 77 score is 0.015591999748923108
# For epoch 0 batch 78 score is 0.015326565661255594
# For epoch 0 batch 79 score is 0.015919472131332723
# For epoch 0 batch 80 score is 0.015194444749344517
# For epoch 0 batch 81 score is 0.015023972899696193
# For epoch 0 batch 82 score is 0.014715687582724601
# For epoch 0 batch 83 score is 0.015141470939580178
# For epoch 0 batch 84 score is 0.014377063716607248
# For epoch 0 batch 85 score is 0.014396428328034172
# For epoch 0 batch 86 score is 0.013710295514120832
# For epoch 0 batch 87 score is 0.014086025484615027
# For epoch 0 batch 88 score is 0.013340764526798103
# For epoch 0 batch 89 score is 0.013036671955185907
# For epoch 0 batch 90 score is 0.013215761548976263
# For epoch 0 batch 91 score is 0.0121429907511092
# For epoch 0 batch 92 score is 0.011744571235695623
# For epoch 0 batch 93 score is 0.01150209521326486
# For epoch 0 batch 94 score is 0.011434567403991534
# For epoch 0 batch 95 score is 0.010867865170652087
# For epoch 0 batch 96 score is 0.01072075889879584
# For epoch 0 batch 97 score is 0.009831650068958635
# For epoch 0 batch 98 score is 0.009489233969189168
# For epoch 0 batch 99 score is 0.008672614750022173
# For epoch 1 batch 0 score is 0.008338462128904938
# For epoch 1 batch 1 score is 0.008020203712430077
# For epoch 1 batch 2 score is 0.0074435977350904466
# For epoch 1 batch 3 score is 0.0068470427399804565
# For epoch 1 batch 4 score is 0.006186062294213901
# For epoch 1 batch 5 score is 0.0058683097483143145
# For epoch 1 batch 6 score is 0.005166266085354699
# For epoch 1 batch 7 score is 0.004940915791655079
# For epoch 1 batch 8 score is 0.00475763863611967
# For epoch 1 batch 9 score is 0.003958981168123689
# For epoch 1 batch 10 score is 0.003564740544604449
# For epoch 1 batch 11 score is 0.0033512423759306403
# For epoch 1 batch 12 score is 0.002939788405887279
# For epoch 1 batch 13 score is 0.002611138056719286
# For epoch 1 batch 14 score is 0.002315271019707727
# For epoch 1 batch 15 score is 0.0022462684083242816
# For epoch 1 batch 16 score is 0.0022706127535900905
# For epoch 1 batch 17 score is 0.0019348713177867404
# For epoch 1 batch 18 score is 0.0017189738223752594
# For epoch 1 batch 19 score is 0.0017530548896689657
# For epoch 1 batch 20 score is 0.0016018193947144545
# For epoch 1 batch 21 score is 0.001609365644142196
# For epoch 1 batch 22 score is 0.0015141181210931176
# For epoch 1 batch 23 score is 0.0015121955916398704
# For epoch 1 batch 24 score is 0.0015529361950579123
# For epoch 1 batch 25 score is 0.0014708414634207084
# For epoch 1 batch 26 score is 0.001463776217313276
# For epoch 1 batch 27 score is 0.0013929052563730736
# For epoch 1 batch 28 score is 0.0013660114792005578
# For epoch 1 batch 29 score is 0.001343063251502937
# For epoch 1 batch 30 score is 0.0013568570584838336
# For epoch 1 batch 31 score is 0.0013057786474126255
# For epoch 1 batch 32 score is 0.0013063581769732137
# For epoch 1 batch 33 score is 0.001458760583834495
# For epoch 1 batch 34 score is 0.0013564215369569832
# For epoch 1 batch 35 score is 0.0012588894137656808
# For epoch 1 batch 36 score is 0.001314024187369086
# For epoch 1 batch 37 score is 0.0013134092537462872
# For epoch 1 batch 38 score is 0.0012262265721844953
# For epoch 1 batch 39 score is 0.0012402968742497972
# For epoch 1 batch 40 score is 0.001215196875455208
# For epoch 1 batch 41 score is 0.0013110068074599936
# For epoch 1 batch 42 score is 0.0012243183418435505
# For epoch 1 batch 43 score is 0.0011904739062490023
# For epoch 1 batch 44 score is 0.0012040623991283383
# For epoch 1 batch 45 score is 0.0011812053477255598
# For epoch 1 batch 46 score is 0.0011805933475789944
# For epoch 1 batch 47 score is 0.0012173963106305063
# For epoch 1 batch 48 score is 0.0012583630129627899
# For epoch 1 batch 49 score is 0.0012106969249824349
# For epoch 1 batch 50 score is 0.001159812398678644
# For epoch 1 batch 51 score is 0.0011475725802291058
# For epoch 1 batch 52 score is 0.0012176510403862349
# For epoch 1 batch 53 score is 0.0012455501128745203
# For epoch 1 batch 54 score is 0.0011521621820245293
# For epoch 1 batch 55 score is 0.001138114514882805
# For epoch 1 batch 56 score is 0.001264015708987588
# For epoch 1 batch 57 score is 0.0011288182757194217
# For epoch 1 batch 58 score is 0.001141678695433457
# For epoch 1 batch 59 score is 0.0012344525258883084
# For epoch 1 batch 60 score is 0.0011694702548343857
# For epoch 1 batch 61 score is 0.0011145345568196352
# For epoch 1 batch 62 score is 0.0013141160808546278
# For epoch 1 batch 63 score is 0.001110598558183555
# For epoch 1 batch 64 score is 0.0011018973952126136
# For epoch 1 batch 65 score is 0.0012263910162337317
# For epoch 1 batch 66 score is 0.0010842965823273482
# For epoch 1 batch 67 score is 0.001105998658317277
# For epoch 1 batch 68 score is 0.0011085244431470699
# For epoch 1 batch 69 score is 0.0011134758321653822
# For epoch 1 batch 70 score is 0.001078020916022883
# For epoch 1 batch 71 score is 0.0010937920458715998
# For epoch 1 batch 72 score is 0.0010849114466285315
# For epoch 1 batch 73 score is 0.0010737523527517099
# For epoch 1 batch 74 score is 0.001089186311512803
# For epoch 1 batch 75 score is 0.001231009748038185
# For epoch 1 batch 76 score is 0.0011440618858061826
# For epoch 1 batch 77 score is 0.0010607374283615064
# For epoch 1 batch 78 score is 0.0010641808490039505
# For epoch 1 batch 79 score is 0.0010543552155275779
# For epoch 1 batch 80 score is 0.0010550108672358444
# For epoch 1 batch 81 score is 0.0010874861942307159
# For epoch 1 batch 82 score is 0.0010621398313959611
# For epoch 1 batch 83 score is 0.0010598764567574675
# For epoch 1 batch 84 score is 0.001032030435439264
# For epoch 1 batch 85 score is 0.0010742175756665174
# For epoch 1 batch 86 score is 0.0010568610691499291
# For epoch 1 batch 87 score is 0.0010291411815774411
# For epoch 1 batch 88 score is 0.0010927690746192697
# For epoch 1 batch 89 score is 0.0011241909116816535
# For epoch 1 batch 90 score is 0.0010666490898136938
# For epoch 1 batch 91 score is 0.001023987970159396
# For epoch 1 batch 92 score is 0.0010381123121514849
# For epoch 1 batch 93 score is 0.0012000863534435732
# For epoch 1 batch 94 score is 0.001012932772965885
# For epoch 1 batch 95 score is 0.0010795715409359816
# For epoch 1 batch 96 score is 0.0010278343774721213
# For epoch 1 batch 97 score is 0.0011131084847817551
# For epoch 1 batch 98 score is 0.0010171908288524212
# For epoch 1 batch 99 score is 0.0010496673579024054
# For epoch 2 batch 0 score is 0.001042805336731687
# For epoch 2 batch 1 score is 0.001071502632830537
# For epoch 2 batch 2 score is 0.0010092904457290688
# For epoch 2 batch 3 score is 0.0010673230644141307
# For epoch 2 batch 4 score is 0.0009994287081798317
# For epoch 2 batch 5 score is 0.0009882906594536952
# For epoch 2 batch 6 score is 0.0010582160688444116
# For epoch 2 batch 7 score is 0.0009936702388801135
# For epoch 2 batch 8 score is 0.0010038940567930618
# For epoch 2 batch 9 score is 0.0010121404713770436
# For epoch 2 batch 10 score is 0.0010561263682638297
# For epoch 2 batch 11 score is 0.0009905233159476434
# For epoch 2 batch 12 score is 0.0009908137265885277
# For epoch 2 batch 13 score is 0.0009704118798440585
# For epoch 2 batch 14 score is 0.0009860531049043792
# For epoch 2 batch 15 score is 0.0009715177746957314
# For epoch 2 batch 16 score is 0.0010699689976305946
# For epoch 2 batch 17 score is 0.0009764558737415795
# For epoch 2 batch 18 score is 0.0009747117437059889
# For epoch 2 batch 19 score is 0.0009916941189954888
# For epoch 2 batch 20 score is 0.0009738854458967277
# For epoch 2 batch 21 score is 0.0009677027875157358
# For epoch 2 batch 22 score is 0.0009875370404208808
# For epoch 2 batch 23 score is 0.000974449036203072
# For epoch 2 batch 24 score is 0.000986391256702165
# For epoch 2 batch 25 score is 0.001037934692339587
# For epoch 2 batch 26 score is 0.001045385650064075
# For epoch 2 batch 27 score is 0.0010516845734213876
# For epoch 2 batch 28 score is 0.0009443540092979441
# For epoch 2 batch 29 score is 0.0009444653623985419
# For epoch 2 batch 30 score is 0.0009476340673005593
# For epoch 2 batch 31 score is 0.0010133091104696736
# For epoch 2 batch 32 score is 0.0009401302814953681
# For epoch 2 batch 33 score is 0.0009674346234534745
# For epoch 2 batch 34 score is 0.0009338500747707639
# For epoch 2 batch 35 score is 0.000955616395262641
# For epoch 2 batch 36 score is 0.0009393754854754809
# For epoch 2 batch 37 score is 0.0009388689048523305
# For epoch 2 batch 38 score is 0.0010624013718175907
# For epoch 2 batch 39 score is 0.0010000975971511765
# For epoch 2 batch 40 score is 0.0010069675554318991
# For epoch 2 batch 41 score is 0.0009523373943489328
# For epoch 2 batch 42 score is 0.0009272616495581332
# For epoch 2 batch 43 score is 0.0009284718744408017
# For epoch 2 batch 44 score is 0.0009733255052285527
# For epoch 2 batch 45 score is 0.0009722684433026196
# For epoch 2 batch 46 score is 0.0009235585613442426
# For epoch 2 batch 47 score is 0.0009160520850521278
# For epoch 2 batch 48 score is 0.0009636325268067806
# For epoch 2 batch 49 score is 0.0009205289345615266
# For epoch 2 batch 50 score is 0.0009226780346117088
# For epoch 2 batch 51 score is 0.0009460374662076877
# For epoch 2 batch 52 score is 0.0009146994137068833
# For epoch 2 batch 53 score is 0.000910663934216482
# For epoch 2 batch 54 score is 0.0009130871424403776
# For epoch 2 batch 55 score is 0.000982104232321035
# For epoch 2 batch 56 score is 0.0009088846339286932
# For epoch 2 batch 57 score is 0.0009376772231571274
# For epoch 2 batch 58 score is 0.0009391902192099584
# For epoch 2 batch 59 score is 0.0009619374483980379
# For epoch 2 batch 60 score is 0.0009926185949010193
# For epoch 2 batch 61 score is 0.0010537380892016181
# For epoch 2 batch 62 score is 0.0009042563593974285
# For epoch 2 batch 63 score is 0.0009144190154701581
# For epoch 2 batch 64 score is 0.0010452793814965543
# For epoch 2 batch 65 score is 0.0009382489521472411
# For epoch 2 batch 66 score is 0.000959733903130697
# For epoch 2 batch 67 score is 0.0009122004810724134
# For epoch 2 batch 68 score is 0.0009065670344703397
# For epoch 2 batch 69 score is 0.001066394870398935
# For epoch 2 batch 70 score is 0.0008957645545910845
# For epoch 2 batch 71 score is 0.0009249096821037814
# For epoch 2 batch 72 score is 0.0008941178170603296
# For epoch 2 batch 73 score is 0.0009871804413855198
# For epoch 2 batch 74 score is 0.0009096059077677965
# For epoch 2 batch 75 score is 0.001073048805282085
# For epoch 2 batch 76 score is 0.0008833236687389921
# For epoch 2 batch 77 score is 0.0009214703692812802
# For epoch 2 batch 78 score is 0.0008873006879732664
# For epoch 2 batch 79 score is 0.0008773790996417653
# For epoch 2 batch 80 score is 0.0008852791273159377
# For epoch 2 batch 81 score is 0.001007097627874524
# For epoch 2 batch 82 score is 0.0008911192625507269
# For epoch 2 batch 83 score is 0.0009095975299204108
# For epoch 2 batch 84 score is 0.0008766806930820925
# For epoch 2 batch 85 score is 0.0009247775625417141
# For epoch 2 batch 86 score is 0.0008791499433288803
# For epoch 2 batch 87 score is 0.0009573626504601844
# For epoch 2 batch 88 score is 0.0008708145382084948
# For epoch 2 batch 89 score is 0.0008860696525358057
# For epoch 2 batch 90 score is 0.0009299879978739898
# For epoch 2 batch 91 score is 0.0008673838794938371
# For epoch 2 batch 92 score is 0.000927563271311038
# For epoch 2 batch 93 score is 0.0008788548980791805
# For epoch 2 batch 94 score is 0.0008804248444710815
# For epoch 2 batch 95 score is 0.0008604327050061189
# For epoch 2 batch 96 score is 0.0008697665423265666
# For epoch 2 batch 97 score is 0.0008584815096445325
# For epoch 2 batch 98 score is 0.000964642134156166
# For epoch 2 batch 99 score is 0.0008668910876779733
# Regression coefficients are [array([[ 0.49486156,  0.0274489 , -0.30483331,  0.71141747, -0.02125012],
#        [-0.4787366 ,  2.09791734,  0.54034191, -0.29477671, -0.26197928],
#        [-0.20040086, -0.23256289,  0.12755591, -0.01981467, -2.55454622]]), array([[ 0.65805764],
#        [ 1.29545962],
#        [-0.5026037 ],
#        [ 0.79338322],
#        [-0.91814959]])]
# Bias [array([-0.3554245 , -2.39323271,  0.18236641,  0.01510151,  2.90456769]), array([0.37205499])]
