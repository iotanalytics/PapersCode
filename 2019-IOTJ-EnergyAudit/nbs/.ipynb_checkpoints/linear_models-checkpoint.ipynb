# %%
import sys
sys.path.append("/home/adityas/UGA/SensorWeb/scripts/Summer2018/code")

from pathlib import Path
import pandas
import matplotlib.pyplot as plotter
import numpy
from scipy.signal import *

# %% [markdown]
# Import data loaders and all

# %%
from model.data_loader import DataLoader

# %%
files = list(Path("../data/").iterdir())
files = sorted(files, key=lambda x: int(str(x).split("/")[-1].split(".")[0].split("_")[-1]))
files[:10]
# Out:
# [PosixPath('../data/run_0.csv'),
#  PosixPath('../data/run_1.csv'),
#  PosixPath('../data/run_2.csv'),
#  PosixPath('../data/run_3.csv'),
#  PosixPath('../data/run_4.csv'),
#  PosixPath('../data/run_5.csv'),
#  PosixPath('../data/run_6.csv'),
#  PosixPath('../data/run_7.csv'),
#  PosixPath('../data/run_8.csv'),
#  PosixPath('../data/run_9.csv')]

# %% [markdown]
# Initialize data loader

# %% [markdown]
# ## Data stats

# %%
dataloader = DataLoader(files)

# %% [markdown]
# Print some statistics to look at distributions

# %%
test_data = dataloader[0]
print(test_data.head(5))
test_data.plot(kind="density")
plotter.legend()
plotter.show()
# Out:
#         cpu      disk   network    energy
# 0  0.636356  0.109643  0.032550  0.204011
# 1  0.878655  0.000000  0.002232  0.228408
# 2  1.000000  0.054926  0.065164  0.288503
# 3  0.890368  0.000000  0.067236  0.247839
# 4  0.879670  0.000000  0.056766  0.242525

# %% [markdown]
# Have a peek at the target function

# %%
# !head ../scripts/exp.log -n 15
# Out:
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# INFO:HighSensitivityLinearEM:Energy meter init with factors cpu:0.24792518649303633 + disk:0.2550646624326527 + net:0.2542521020480565
# INFO:Device:Device initialised
# DEBUG:Device:Device in state compute
# DEBUG:Device:Device in state net_send
# DEBUG:Device:Device in state read
# DEBUG:Device:Device in state compute

# %% [markdown]
# Take a look at the waveforms

# %%
test_data[:100].plot()
plotter.legend()
plotter.show()

# %%
corr = test_data.corr()
plotter.imshow(corr, cmap="gray")
plotter.xticks(numpy.arange(len(corr.columns)))
plotter.yticks(numpy.arange(len(corr.index)))
plotter.xlabel(list(corr.columns))
plotter.ylabel(list(reversed(list(corr.index))))
plotter.show()

# %% [markdown]
# Clean up

# %%
del test_data

# %% [markdown]
# ## Learn function

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error

# %%
regressor = SGDRegressor()

# %%
for i in range(1):
    for batch in range(len(dataloader)):
        data = dataloader[i]
        y = data["energy"]
        X = data.drop("energy", axis=1)
        
        regressor.partial_fit(X, y)
        
        print(f"For epoch {i} batch {batch} score is {mean_absolute_error(y_pred=regressor.predict(X), y_true=y)}")

print(f"Regression coefficients are {regressor.coef_}")
print(f"Bias {regressor.intercept_}")
# Out:
# /home/adityas/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# For epoch 0 batch 0 score is 0.011880201905809646
# For epoch 0 batch 1 score is 0.004087003883961063
# For epoch 0 batch 2 score is 0.0016489601125555537
# For epoch 0 batch 3 score is 0.0007569786951870353
# For epoch 0 batch 4 score is 0.00039710082446057485
# For epoch 0 batch 5 score is 0.00024326604246058402
# For epoch 0 batch 6 score is 0.0001759787832055851
# For epoch 0 batch 7 score is 0.00014399951829259874
# For epoch 0 batch 8 score is 0.00012954711111269382
# For epoch 0 batch 9 score is 0.00012176816183006617
# For epoch 0 batch 10 score is 0.00011835505613456426
# For epoch 0 batch 11 score is 0.00011695131506660068
# For epoch 0 batch 12 score is 0.00011677240179925173
# For epoch 0 batch 13 score is 0.00011500626167735187
# For epoch 0 batch 14 score is 0.00011542054388015564
# For epoch 0 batch 15 score is 0.00011442772901214673
# For epoch 0 batch 16 score is 0.00011459655704737581
# For epoch 0 batch 17 score is 0.00011510132356846394
# For epoch 0 batch 18 score is 0.00011411775954638352
# For epoch 0 batch 19 score is 0.00011495555990278558
# For epoch 0 batch 20 score is 0.00011494627261006457
# For epoch 0 batch 21 score is 0.00011512483532768543
# For epoch 0 batch 22 score is 0.00011466957220831001
# For epoch 0 batch 23 score is 0.0001148977621327576
# For epoch 0 batch 24 score is 0.00011481246799317821
# For epoch 0 batch 25 score is 0.00011468041648838282
# For epoch 0 batch 26 score is 0.00011483293899797063
# For epoch 0 batch 27 score is 0.00011468292160209353
# For epoch 0 batch 28 score is 0.00011442849689841525
# For epoch 0 batch 29 score is 0.00011461321660974146
# For epoch 0 batch 30 score is 0.00011481347478619671
# For epoch 0 batch 31 score is 0.00011465444761414724
# For epoch 0 batch 32 score is 0.00011489148397121245
# For epoch 0 batch 33 score is 0.00011476905531547583
# For epoch 0 batch 34 score is 0.00011489780695278019
# For epoch 0 batch 35 score is 0.0001150974032353875
# For epoch 0 batch 36 score is 0.00011475127767861797
# For epoch 0 batch 37 score is 0.00011486019161261229
# For epoch 0 batch 38 score is 0.00011482608376700158
# For epoch 0 batch 39 score is 0.00011454857048741083
# For epoch 0 batch 40 score is 0.00011480496767717338
# For epoch 0 batch 41 score is 0.00011489970896516698
# For epoch 0 batch 42 score is 0.00011421724717742487
# For epoch 0 batch 43 score is 0.000114551662269308
# For epoch 0 batch 44 score is 0.00011475835453229319
# For epoch 0 batch 45 score is 0.00011481176253560234
# For epoch 0 batch 46 score is 0.00011446860334144923
# For epoch 0 batch 47 score is 0.00011445165376218724
# For epoch 0 batch 48 score is 0.0001146198592816455
# For epoch 0 batch 49 score is 0.00011521474901122086
# For epoch 0 batch 50 score is 0.00011461088425690641
# For epoch 0 batch 51 score is 0.00011446550152136857
# For epoch 0 batch 52 score is 0.00011453232157422753
# For epoch 0 batch 53 score is 0.00011463204780374874
# For epoch 0 batch 54 score is 0.00011462657273737122
# For epoch 0 batch 55 score is 0.00011474286291319934
# For epoch 0 batch 56 score is 0.00011465997131127692
# For epoch 0 batch 57 score is 0.00011454999549999761
# For epoch 0 batch 58 score is 0.0001152365997010056
# For epoch 0 batch 59 score is 0.00011448360126816587
# For epoch 0 batch 60 score is 0.00011431623327575625
# For epoch 0 batch 61 score is 0.00011468835674162899
# For epoch 0 batch 62 score is 0.00011438220006618473
# For epoch 0 batch 63 score is 0.00011490798801728026
# For epoch 0 batch 64 score is 0.00011482421764301975
# For epoch 0 batch 65 score is 0.0001144184984478993
# For epoch 0 batch 66 score is 0.00011485720267027878
# For epoch 0 batch 67 score is 0.00011421563216041317
# For epoch 0 batch 68 score is 0.0001146324073144604
# For epoch 0 batch 69 score is 0.00011487278055286157
# For epoch 0 batch 70 score is 0.00011482469566617741
# For epoch 0 batch 71 score is 0.00011470409859821319
# For epoch 0 batch 72 score is 0.00011451918749647529
# For epoch 0 batch 73 score is 0.00011454567009665439
# For epoch 0 batch 74 score is 0.00011473777280461292
# For epoch 0 batch 75 score is 0.00011438685973086816
# For epoch 0 batch 76 score is 0.00011516902792961566
# For epoch 0 batch 77 score is 0.00011520188760933608
# For epoch 0 batch 78 score is 0.00011480490234854096
# For epoch 0 batch 79 score is 0.00011544360197674676
# For epoch 0 batch 80 score is 0.0001149194474610114
# For epoch 0 batch 81 score is 0.00011470447436882824
# For epoch 0 batch 82 score is 0.00011467498505236752
# For epoch 0 batch 83 score is 0.00011416997839356153
# For epoch 0 batch 84 score is 0.00011523589932512315
# For epoch 0 batch 85 score is 0.00011457162584992184
# For epoch 0 batch 86 score is 0.00011468707936095572
# For epoch 0 batch 87 score is 0.00011459209103562254
# For epoch 0 batch 88 score is 0.0001146662322119392
# For epoch 0 batch 89 score is 0.00011460404542728833
# For epoch 0 batch 90 score is 0.00011481441692914113
# For epoch 0 batch 91 score is 0.00011501738640774222
# For epoch 0 batch 92 score is 0.00011440978392361798
# For epoch 0 batch 93 score is 0.00011445103844002439
# For epoch 0 batch 94 score is 0.00011502444379524472
# For epoch 0 batch 95 score is 0.00011504155923064984
# For epoch 0 batch 96 score is 0.00011525587362835742
# For epoch 0 batch 97 score is 0.00011469247232734086
# For epoch 0 batch 98 score is 0.00011513709236433855
# For epoch 0 batch 99 score is 0.00011431661013615463
# Regression coefficients are [0.24771714 0.25476874 0.25396379]
# Bias [0.01039848]

# %% [markdown]
# ## Repeat for low sensitivity

# %%
files = list(Path("../data/low_sense/").iterdir())
files = sorted(files, key=lambda x: int(str(x).split("/")[-1].split(".")[0].split("_")[-1]))
files[:10]
# Out:
# [PosixPath('../data/low_sense/run_0.csv'),
#  PosixPath('../data/low_sense/run_1.csv'),
#  PosixPath('../data/low_sense/run_2.csv'),
#  PosixPath('../data/low_sense/run_3.csv'),
#  PosixPath('../data/low_sense/run_4.csv'),
#  PosixPath('../data/low_sense/run_5.csv'),
#  PosixPath('../data/low_sense/run_6.csv'),
#  PosixPath('../data/low_sense/run_7.csv'),
#  PosixPath('../data/low_sense/run_8.csv'),
#  PosixPath('../data/low_sense/run_9.csv')]

# %% [markdown]
# Initialize data loader

# %% [markdown]
# ## Data stats

# %%
dataloader = DataLoader(files)

# %% [markdown]
# Print some statistics to look at distributions

# %%
test_data = dataloader[0]
print(test_data.head(5))
test_data.plot(kind="density")
plotter.legend()
plotter.show()
# Out:
#         cpu      disk   network    energy
# 0  0.384791  0.000000  0.094509  0.546326
# 1  0.749329  0.000000  0.136154  0.585482
# 2  0.944901  0.000000  0.000000  0.590831
# 3  1.000000  0.092799  0.000000  0.605568
# 4  0.774858  0.000000  0.052748  0.579697

# %% [markdown]
# Have a peek at the target function

# %%
# !head ../scripts/lowsense.log -n 15
# Out:
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# DEBUG:CPU:CPU component initialized
# DEBUG:DiskIO:Disk IO component initialized
# DEBUG:Network:Networking component initialized
# INFO:LowSensitivityLinearEM:Energy meter init with factorscpu:0.09612754537369309 + disk:0.10173242858102917 +net:0.0987955747978398
# INFO:Device:Device initialised
# DEBUG:Device:Device in state compute
# DEBUG:Device:Device in state net_send
# DEBUG:Device:Device in state read
# DEBUG:Device:Device in state compute

# %% [markdown]
# Take a look at the waveforms

# %%
test_data[:100].plot()
plotter.legend()
plotter.show()

# %%
corr = test_data.corr()
plotter.imshow(corr, cmap="gray")
plotter.xticks(numpy.arange(len(corr.columns)))
plotter.yticks(numpy.arange(len(corr.index)))
plotter.xlabel(list(corr.columns))
plotter.ylabel(list(reversed(list(corr.index))))
plotter.show()

# %% [markdown]
# Clean up

# %%
del test_data

# %% [markdown]
# ## Learn function

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error

# %%
regressor = SGDRegressor()

# %%
for i in range(1):
    for batch in range(len(dataloader)):
        data = dataloader[i]
        y = data["energy"]
        X = data.drop("energy", axis=1)
        
        regressor.partial_fit(X, y)
        
        print(f"For epoch {i} batch {batch} score is {mean_absolute_error(y_pred=regressor.predict(X), y_true=y)}")

print(f"Regression coefficients are {regressor.coef_}")
print(f"Bias {regressor.intercept_}")
# Out:
# /home/adityas/miniconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# For epoch 0 batch 0 score is 0.007593375730598193
# For epoch 0 batch 1 score is 0.0025338557173057484
# For epoch 0 batch 2 score is 0.0009547249838449302
# For epoch 0 batch 3 score is 0.0003737245014650867
# For epoch 0 batch 4 score is 0.000140260091620279
# For epoch 0 batch 5 score is 4.1031417644651035e-05
# For epoch 0 batch 6 score is 8.988367043000856e-06
# For epoch 0 batch 7 score is 2.5905105771532812e-05
# For epoch 0 batch 8 score is 3.575684018924434e-05
# For epoch 0 batch 9 score is 3.99298052278268e-05
# For epoch 0 batch 10 score is 4.265254533640526e-05
# For epoch 0 batch 11 score is 4.38344642789988e-05
# For epoch 0 batch 12 score is 4.452068295250477e-05
# For epoch 0 batch 13 score is 4.4792054801254274e-05
# For epoch 0 batch 14 score is 4.504392735827015e-05
# For epoch 0 batch 15 score is 4.4997439344730345e-05
# For epoch 0 batch 16 score is 4.505343922666567e-05
# For epoch 0 batch 17 score is 4.496242177996835e-05
# For epoch 0 batch 18 score is 4.5215783207447464e-05
# For epoch 0 batch 19 score is 4.505906762173207e-05
# For epoch 0 batch 20 score is 4.492641663268951e-05
# For epoch 0 batch 21 score is 4.477212621426371e-05
# For epoch 0 batch 22 score is 4.510283819898379e-05
# For epoch 0 batch 23 score is 4.472698463121345e-05
# For epoch 0 batch 24 score is 4.500897752627722e-05
# For epoch 0 batch 25 score is 4.517120010999712e-05
# For epoch 0 batch 26 score is 4.523241924139499e-05
# For epoch 0 batch 27 score is 4.486486145496998e-05
# For epoch 0 batch 28 score is 4.5029396287234004e-05
# For epoch 0 batch 29 score is 4.4999347639599786e-05
# For epoch 0 batch 30 score is 4.493611581514941e-05
# For epoch 0 batch 31 score is 4.4978580466739415e-05
# For epoch 0 batch 32 score is 4.4927662239228304e-05
# For epoch 0 batch 33 score is 4.490056212628666e-05
# For epoch 0 batch 34 score is 4.500940536766186e-05
# For epoch 0 batch 35 score is 4.509266961569131e-05
# For epoch 0 batch 36 score is 4.516090610477327e-05
# For epoch 0 batch 37 score is 4.509093655335249e-05
# For epoch 0 batch 38 score is 4.527933940178186e-05
# For epoch 0 batch 39 score is 4.52131153947421e-05
# For epoch 0 batch 40 score is 4.5134617999111384e-05
# For epoch 0 batch 41 score is 4.514297702450579e-05
# For epoch 0 batch 42 score is 4.507590741152752e-05
# For epoch 0 batch 43 score is 4.495561388636341e-05
# For epoch 0 batch 44 score is 4.5013184776094034e-05
# For epoch 0 batch 45 score is 4.492924025493606e-05
# For epoch 0 batch 46 score is 4.5272273484639906e-05
# For epoch 0 batch 47 score is 4.5051418457333955e-05
# For epoch 0 batch 48 score is 4.516269756983718e-05
# For epoch 0 batch 49 score is 4.524646871168323e-05
# For epoch 0 batch 50 score is 4.501911811541069e-05
# For epoch 0 batch 51 score is 4.5105387904217586e-05
# For epoch 0 batch 52 score is 4.4927865622381505e-05
# For epoch 0 batch 53 score is 4.5130147954532005e-05
# For epoch 0 batch 54 score is 4.4988595881569155e-05
# For epoch 0 batch 55 score is 4.4929033515139844e-05
# For epoch 0 batch 56 score is 4.481487324995472e-05
# For epoch 0 batch 57 score is 4.5123197732583184e-05
# For epoch 0 batch 58 score is 4.5105767483003605e-05
# For epoch 0 batch 59 score is 4.503292801242791e-05
# For epoch 0 batch 60 score is 4.486968998175064e-05
# For epoch 0 batch 61 score is 4.504707355147579e-05
# For epoch 0 batch 62 score is 4.492118433199847e-05
# For epoch 0 batch 63 score is 4.534687092311924e-05
# For epoch 0 batch 64 score is 4.51279150913568e-05
# For epoch 0 batch 65 score is 4.511110312799563e-05
# For epoch 0 batch 66 score is 4.5147337779473445e-05
# For epoch 0 batch 67 score is 4.5348266638650124e-05
# For epoch 0 batch 68 score is 4.498489581177664e-05
# For epoch 0 batch 69 score is 4.514699887566831e-05
# For epoch 0 batch 70 score is 4.5064322005574597e-05
# For epoch 0 batch 71 score is 4.522986933722811e-05
# For epoch 0 batch 72 score is 4.53909306397854e-05
# For epoch 0 batch 73 score is 4.537309143364826e-05
# For epoch 0 batch 74 score is 4.4993272554568434e-05
# For epoch 0 batch 75 score is 4.5324341085063624e-05
# For epoch 0 batch 76 score is 4.511280882334038e-05
# For epoch 0 batch 77 score is 4.515012943655734e-05
# For epoch 0 batch 78 score is 4.510735928698757e-05
# For epoch 0 batch 79 score is 4.488401749284936e-05
# For epoch 0 batch 80 score is 4.5204475890563755e-05
# For epoch 0 batch 81 score is 4.487473479164188e-05
# For epoch 0 batch 82 score is 4.494713553755272e-05
# For epoch 0 batch 83 score is 4.502552695220632e-05
# For epoch 0 batch 84 score is 4.50989721878438e-05
# For epoch 0 batch 85 score is 4.512626248674165e-05
# For epoch 0 batch 86 score is 4.5021646232076486e-05
# For epoch 0 batch 87 score is 4.504451658874502e-05
# For epoch 0 batch 88 score is 4.505117579648688e-05
# For epoch 0 batch 89 score is 4.522325851680646e-05
# For epoch 0 batch 90 score is 4.5191264392373095e-05
# For epoch 0 batch 91 score is 4.514171867235621e-05
# For epoch 0 batch 92 score is 4.494948677306363e-05
# For epoch 0 batch 93 score is 4.512378050001796e-05
# For epoch 0 batch 94 score is 4.5019853557921883e-05
# For epoch 0 batch 95 score is 4.5071115376597845e-05
# For epoch 0 batch 96 score is 4.508189119834436e-05
# For epoch 0 batch 97 score is 4.500597481653072e-05
# For epoch 0 batch 98 score is 4.502012713016505e-05
# For epoch 0 batch 99 score is 4.51216265526007e-05
# Regression coefficients are [0.0960454  0.10161403 0.09868324]
# Bias [0.50015559]

# %% [markdown]
# Try NNF

# %%
from sklearn.decomposition import NMF

# %%
data = dataloader[0]
y = data["energy"]
X = data.drop("energy", axis=1)

# %%
nmf = NMF(n_components=3)

# %%
nmf.fit(X.as_matrix())
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=3, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
nmf.reconstruction_err_
# Out:
# 0.029890079170381192
